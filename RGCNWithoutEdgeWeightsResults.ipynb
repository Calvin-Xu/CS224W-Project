# %%
# Install pykeen - package that is used to set up the pipeline
pip install pykeen
# Out:
# Requirement already satisfied: pykeen in /usr/local/lib/python3.10/dist-packages (1.11.0)
# Requirement already satisfied: dataclasses-json in /usr/local/lib/python3.10/dist-packages (from pykeen) (0.6.7)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pykeen) (1.26.4)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from pykeen) (1.13.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from pykeen) (8.1.7)
# Requirement already satisfied: click-default-group in /usr/local/lib/python3.10/dist-packages (from pykeen) (1.2.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from pykeen) (1.5.2)
# Requirement already satisfied: torch>=2.0 in /usr/local/lib/python3.10/dist-packages (from pykeen) (2.5.1+cu121)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from pykeen) (4.66.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from pykeen) (2.32.3)
# Requirement already satisfied: optuna>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from pykeen) (4.1.0)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from pykeen) (2.2.2)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from pykeen) (0.9.0)
# Requirement already satisfied: more-click in /usr/local/lib/python3.10/dist-packages (from pykeen) (0.1.2)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from pykeen) (10.5.0)
# Requirement already satisfied: pystow>=0.4.3 in /usr/local/lib/python3.10/dist-packages (from pykeen) (0.6.1)
# Requirement already satisfied: docdata in /usr/local/lib/python3.10/dist-packages (from pykeen) (0.0.4)
# Requirement already satisfied: class-resolver>=0.5.1 in /usr/local/lib/python3.10/dist-packages (from pykeen) (0.5.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from pykeen) (6.0.2)
# Requirement already satisfied: torch-max-mem>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from pykeen) (0.1.3)
# Requirement already satisfied: torch-ppr>=0.0.7 in /usr/local/lib/python3.10/dist-packages (from pykeen) (0.0.8)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from pykeen) (4.12.2)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from optuna>=2.0.0->pykeen) (1.14.0)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.10/dist-packages (from optuna>=2.0.0->pykeen) (6.9.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna>=2.0.0->pykeen) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.10/dist-packages (from optuna>=2.0.0->pykeen) (2.0.36)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->pykeen) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->pykeen) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->pykeen) (2024.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=2.0->pykeen) (3.16.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=2.0->pykeen) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0->pykeen) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=2.0->pykeen) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0->pykeen) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=2.0->pykeen) (1.3.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json->pykeen) (3.23.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json->pykeen) (0.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->pykeen) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->pykeen) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->pykeen) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->pykeen) (2024.8.30)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->pykeen) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->pykeen) (3.5.0)
# Requirement already satisfied: Mako in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna>=2.0.0->pykeen) (1.3.8)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.0->pykeen) (1.16.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.4.2->optuna>=2.0.0->pykeen) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->pykeen) (1.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=2.0->pykeen) (3.0.2)

# %%
# Mount Google Drive to work on relevant files
from google.colab import drive
drive.mount('/content/drive')

# Import necessary packages
import pickle
import numpy as np
from pykeen.pipeline import pipeline
from pykeen.triples import TriplesFactory
from typing import List, Tuple
from pykeen.predict import predict_target

# Load the Graph from pickle
graph_path = "/content/drive/MyDrive/Colabs/data/graph_w_covid_genes_treatments_string_cif_coalesced_3.pkl"
with open(graph_path, "rb") as f:
    graph = pickle.load(f)

# Extract triples from the graph
triples = []
for source, target, data in graph.edges(data=True):
    relation = data.get('relation', 'related_to')  # Default relation if not specified
    triples.append((str(source), str(relation), str(target)))

# Convert triples to numpy array
triples_array = np.array(triples)

# Split the triples into training, validation, and testing sets
training_triples = triples_array[:int(0.8 * len(triples_array))]
validation_triples = triples_array[int(0.8 * len(triples_array)):int(0.9 * len(triples_array))]
testing_triples = triples_array[int(0.9 * len(triples_array)):]

training_factory = TriplesFactory.from_labeled_triples(training_triples)
validation_factory = TriplesFactory.from_labeled_triples(validation_triples)
testing_factory = TriplesFactory.from_labeled_triples(testing_triples)

# Create a RGCN pipeline to train the model
pipeline_result = pipeline(
    training=training_factory,
    testing=testing_factory,
    validation=validation_factory,
    model='RGCN',
    training_loop='sLCWA',
    optimizer='Adam',
    model_kwargs={
        'embedding_dim': 100,
        'num_layers': 2,
    },
    training_kwargs={
          'num_epochs': 50,
          'batch_size': 6000,
    },
    random_seed=42,
    use_tqdm=True,
    device='cuda'
)
# Out:
# WARNING:pykeen.pipeline.api:No random seed is specified. Setting to 452717203.
# INFO:pykeen.pipeline.api:Using device: cuda
# INFO:pykeen.nn.message_passing:No num_bases was provided. Using sqrt(num_relations)=11.
# INFO:pykeen.nn.message_passing:No num_bases was provided. Using sqrt(num_relations)=11.
# INFO:pykeen.nn.message_passing:No num_bases was provided. Using sqrt(num_relations)=11.
# INFO:pykeen.nn.message_passing:No num_bases was provided. Using sqrt(num_relations)=11.
# WARNING:pykeen.nn.message_passing:Layers RGCNLayer(
#   (fwd): BasesDecomposition(
#     (relation_representations): LowRankRepresentation(
#       (bases): Embedding(
#         (_embeddings): Embedding(11, 10000)
#       )
#     )
#   )
#   (bwd): BasesDecomposition(
#     (relation_representations): LowRankRepresentation(
#       (bases): Embedding(
#         (_embeddings): Embedding(11, 10000)
#       )
#     )
#   )
#   (self_loop): Linear(in_features=100, out_features=100, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
# ) has parameters, but no reset_parameters.
# WARNING:pykeen.nn.message_passing:Layers RGCNLayer(
#   (fwd): BasesDecomposition(
#     (relation_representations): LowRankRepresentation(
#       (bases): Embedding(
#         (_embeddings): Embedding(11, 10000)
#       )
#     )
#   )
#   (bwd): BasesDecomposition(
#     (relation_representations): LowRankRepresentation(
#       (bases): Embedding(
#         (_embeddings): Embedding(11, 10000)
#       )
#     )
#   )
#   (self_loop): Linear(in_features=100, out_features=100, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
# ) has parameters, but no reset_parameters.
# WARNING:pykeen.training.training_loop:Using RGCN without graph-based sampling! Please select sampler="schlichtkrull" instead of None.
# WARNING:pykeen.training.training_loop:Using RGCN without graph-based sampling! Please select sampler="schlichtkrull" instead of None.
# WARNING:pykeen.nn.message_passing:Layers RGCNLayer(
#   (fwd): BasesDecomposition(
#     (relation_representations): LowRankRepresentation(
#       (bases): Embedding(
#         (_embeddings): Embedding(11, 10000)
#       )
#     )
#   )
#   (bwd): BasesDecomposition(
#     (relation_representations): LowRankRepresentation(
#       (bases): Embedding(
#         (_embeddings): Embedding(11, 10000)
#       )
#     )
#   )
#   (self_loop): Linear(in_features=100, out_features=100, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
# ) has parameters, but no reset_parameters.
# WARNING:pykeen.nn.message_passing:Layers RGCNLayer(
#   (fwd): BasesDecomposition(
#     (relation_representations): LowRankRepresentation(
#       (bases): Embedding(
#         (_embeddings): Embedding(11, 10000)
#       )
#     )
#   )
#   (bwd): BasesDecomposition(
#     (relation_representations): LowRankRepresentation(
#       (bases): Embedding(
#         (_embeddings): Embedding(11, 10000)
#       )
#     )
#   )
#   (self_loop): Linear(in_features=100, out_features=100, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
# ) has parameters, but no reset_parameters.
# WARNING:pykeen.nn.message_passing:Layers RGCNLayer(
#   (fwd): BasesDecomposition(
#     (relation_representations): LowRankRepresentation(
#       (bases): Embedding(
#         (_embeddings): Embedding(11, 10000)
#       )
#     )
#   )
#   (bwd): BasesDecomposition(
#     (relation_representations): LowRankRepresentation(
#       (bases): Embedding(
#         (_embeddings): Embedding(11, 10000)
#       )
#     )
#   )
#   (self_loop): Linear(in_features=100, out_features=100, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
# ) has parameters, but no reset_parameters.
# WARNING:pykeen.nn.message_passing:Layers RGCNLayer(
#   (fwd): BasesDecomposition(
#     (relation_representations): LowRankRepresentation(
#       (bases): Embedding(
#         (_embeddings): Embedding(11, 10000)
#       )
#     )
#   )
#   (bwd): BasesDecomposition(
#     (relation_representations): LowRankRepresentation(
#       (bases): Embedding(
#         (_embeddings): Embedding(11, 10000)
#       )
#     )
#   )
#   (self_loop): Linear(in_features=100, out_features=100, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
# ) has parameters, but no reset_parameters.
# Training epochs on cuda:0:   0%|          | 0/50 [00:00<?, ?epoch/s]
# Training batches on cuda:0:   0%|          | 0/674 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/674 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/674 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/674 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/674 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/674 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/674 [00:00<?, ?batch/s]

# %%
# Import necessary modules
import os
import pickle

# Retrieve the trained model from the pipeline result
model = pipeline_result.model

# Define the path where the model will be saved
save_path = '/content/drive/MyDrive/my_models/trained_rgcn_new_graph_model.pkl'
directory = os.path.dirname(save_path)

# Check if the directory exists, and if not, create it
if not os.path.exists(directory):
    os.makedirs(directory)

# Save the model to the specified path using pickle
with open(save_path, 'wb') as f:
    pickle.dump(model, f)

# %%
# Get evaluation results
results = pipeline_result.metric_results.to_dict()
print("\nModel Evaluation Results:")
print(results)

# Get embeddings correctly
entity_embeddings = result.model.entity_representations[0](indices=None).cpu().detach().numpy()
relation_embeddings = result.model.relation_representations[0](indices=None).cpu().detach().numpy()
# Out:
# Model Evaluation Results:
# {'head': {'optimistic': {'adjusted_geometric_mean_rank_index': 0.1387197586492378, 'inverse_harmonic_mean_rank': 0.0006024196282459551, 'variance': 691748385.8013566, 'inverse_median_rank': 2.356989652815424e-05, 'adjusted_inverse_harmonic_mean_rank': 0.000472985407946379, 'inverse_geometric_mean_rank': 3.4012427814031914e-05, 'inverse_arithmetic_mean_rank': 2.3222912661772754e-05, 'adjusted_arithmetic_mean_rank_index': 0.07182688188059483, 'count': 505082.0, 'standard_deviation': 26301.109972800703, 'adjusted_arithmetic_mean_rank': 0.9281746663420413, 'z_inverse_harmonic_mean_rank': 79.86278921712818, 'median_rank': 42427.0, 'arithmetic_mean_rank': 43060.92067624663, 'harmonic_mean_rank': 1659.9724728619256, 'z_arithmetic_mean_rank': 88.41456327743163, 'median_absolute_deviation': 32744.752597914725, 'geometric_mean_rank': 29401.017929906415, 'z_geometric_mean_rank': 98.74585013856847, 'hits_at_1': 0.00010097370327986347, 'hits_at_3': 0.00032271987518858324, 'hits_at_5': 0.0005464459236322023, 'hits_at_10': 0.0011899057974744695, 'z_hits_at_k': 74.08378134288893, 'adjusted_hits_at_k': 0.0010822466302137456}, 'realistic': {'adjusted_geometric_mean_rank_index': 0.13871776635124822, 'inverse_harmonic_mean_rank': 0.0006024196627549827, 'variance': 691748352.0, 'inverse_median_rank': 2.3569897166453302e-05, 'adjusted_inverse_harmonic_mean_rank': 0.00047298544245987585, 'inverse_geometric_mean_rank': 3.401234789635055e-05, 'inverse_arithmetic_mean_rank': 2.322291402379051e-05, 'adjusted_arithmetic_mean_rank_index': 0.07182694024172387, 'count': 505082.0, 'standard_deviation': 26301.109375, 'adjusted_arithmetic_mean_rank': 0.9281746079821702, 'z_inverse_harmonic_mean_rank': 79.86279504467399, 'median_rank': 42427.0, 'arithmetic_mean_rank': 43060.91796875, 'harmonic_mean_rank': 1659.9723777720083, 'z_arithmetic_mean_rank': 88.41463511646475, 'median_absolute_deviation': 32744.752597914725, 'geometric_mean_rank': 29401.0859375, 'z_geometric_mean_rank': 98.74443194724063, 'hits_at_1': 0.00010097370327986347, 'hits_at_3': 0.00032271987518858324, 'hits_at_5': 0.0005464459236322023, 'hits_at_10': 0.0011899057974744695, 'z_hits_at_k': 74.08378134288893, 'adjusted_hits_at_k': 0.0010822466302137456}, 'pessimistic': {'adjusted_geometric_mean_rank_index': 0.1387197114763168, 'inverse_harmonic_mean_rank': 0.0006024196194802362, 'variance': 691748414.4216688, 'inverse_median_rank': 2.356989652815424e-05, 'adjusted_inverse_harmonic_mean_rank': 0.00047298539917952476, 'inverse_geometric_mean_rank': 3.401242595121093e-05, 'inverse_arithmetic_mean_rank': 2.3222911760587835e-05, 'adjusted_arithmetic_mean_rank_index': 0.07182684586120802, 'count': 505082.0, 'standard_deviation': 26301.110516890134, 'adjusted_arithmetic_mean_rank': 0.9281747023606518, 'z_inverse_harmonic_mean_rank': 79.86278773685962, 'median_rank': 42427.0, 'arithmetic_mean_rank': 43060.92234726242, 'harmonic_mean_rank': 1659.9724970159398, 'z_arithmetic_mean_rank': 88.41451893973704, 'median_absolute_deviation': 32744.752597914725, 'geometric_mean_rank': 29401.019540165955, 'z_geometric_mean_rank': 98.74581655914017, 'hits_at_1': 0.00010097370327986347, 'hits_at_3': 0.00032271987518858324, 'hits_at_5': 0.0005464459236322023, 'hits_at_10': 0.0011899057974744695, 'z_hits_at_k': 74.08378134288893, 'adjusted_hits_at_k': 0.0010822466302137456}}, 'tail': {'optimistic': {'adjusted_geometric_mean_rank_index': 0.09962278104140843, 'inverse_harmonic_mean_rank': 0.00014906226739515847, 'variance': 663673715.1309508, 'inverse_median_rank': 2.4324390065919095e-05, 'adjusted_inverse_harmonic_mean_rank': 1.912834898070315e-05, 'inverse_geometric_mean_rank': 3.265259480958989e-05, 'inverse_arithmetic_mean_rank': 2.352761011691869e-05, 'adjusted_arithmetic_mean_rank_index': 0.08066330193273996, 'count': 505082.0, 'standard_deviation': 25761.865521172003, 'adjusted_arithmetic_mean_rank': 0.9193384428012881, 'z_inverse_harmonic_mean_rank': 3.223791432154343, 'median_rank': 41111.0, 'arithmetic_mean_ran ...

# %%
# Define the list of COVID-related diseases
COV_disease_list = [
    "Disease::SARS-CoV2 E",
    "Disease::SARS-CoV2 M",
    "Disease::SARS-CoV2 N",
    "Disease::SARS-CoV2 Spike",
    "Disease::SARS-CoV2 nsp1",
    "Disease::SARS-CoV2 nsp10",
    "Disease::SARS-CoV2 nsp11",
    "Disease::SARS-CoV2 nsp12",
    "Disease::SARS-CoV2 nsp13",
    "Disease::SARS-CoV2 nsp14",
    "Disease::SARS-CoV2 nsp15",
    "Disease::SARS-CoV2 nsp2",
    "Disease::SARS-CoV2 nsp4",
    "Disease::SARS-CoV2 nsp5",
    "Disease::SARS-CoV2 nsp5_C145A",
    "Disease::SARS-CoV2 nsp6",
    "Disease::SARS-CoV2 nsp7",
    "Disease::SARS-CoV2 nsp8",
    "Disease::SARS-CoV2 nsp9",
    "Disease::SARS-CoV2 orf10",
    "Disease::SARS-CoV2 orf3a",
    "Disease::SARS-CoV2 orf3b",
    "Disease::SARS-CoV2 orf6",
    "Disease::SARS-CoV2 orf7a",
    "Disease::SARS-CoV2 orf8",
    "Disease::SARS-CoV2 orf9b",
    "Disease::SARS-CoV2 orf9c",
    "Disease::MESH:D045169",
    "Disease::MESH:D045473",
    "Disease::MESH:D001351",
    "Disease::MESH:D065207",
    "Disease::MESH:D028941",
    "Disease::MESH:D058957",
    "Disease::MESH:D006517",
]

# %%
def get_top_predictions(
    model,
    training_factory,
    relation: str,
    tail_entities: List[str],
    k: int = 20
) -> dict:
    """
    Get top 20 compund predictions for given tail (COVID) entities and relation.
    """
    results = {}

    for tail in tail_entities:
        try:
            # Use predict_target to get predictions
            predictions = predict_target(
                model=model,
                tail=tail,
                relation=relation,
                triples_factory=training_factory
            )

            # Get the results as a dataframe and apply the filter
            df = predictions.df

            # Filter for only Compound predictions
            compound_df = df[df['head_label'].str.startswith('Compound::')].sort_values('score', ascending=False)

            if compound_df.empty:
                print(f"Warning: No compound predictions found for {tail}")
                continue

            # Get top k predictions
            top_k_df = compound_df.head(k)

            # Convert to list of (compound, score) tuples
            head_scores = list(zip(top_k_df['head_label'], top_k_df['score']))
            results[tail] = head_scores

        except KeyError as e:
            print(f"Warning: Entity or relation not found in training data: {e}")
            continue

        except Exception as e:
            print(f"Error predicting for {tail}: {str(e)}")
            continue

    return results

# Get predictions for COVID diseases
relation = "DRKG::Treats::Compound:Disease"
predictions = get_top_predictions(
    result.model,
    train_factory,
    relation,
    COV_disease_list
)

# Print results
print("\nTop 20 predicted compounds for each disease:")
for disease, compounds in predictions.items():
    if compounds:  # Only print if we have compound predictions
        print(f"\n{disease}:")
        for i, (compound, score) in enumerate(compounds, 1):
            print(f"{i}. {compound} (score: {score:.4f})")
# Out:
# Top 20 predicted compounds for each disease:
#
# Disease::SARS-CoV2 E:
# 1. Compound::CHEMBL2108712 (score: 0.6998)
# 2. Compound::CHEMBL2109592 (score: 0.5862)
# 3. Compound::brenda:135439 (score: 0.5665)
# 4. Compound::brenda:169662 (score: 0.4908)
# 5. Compound::CHEMBL3707379 (score: 0.4628)
# 6. Compound::DB05296 (score: 0.4618)
# 7. Compound::brenda:224348 (score: 0.4513)
# 8. Compound::MESH:D009842 (score: 0.4394)
# 9. Compound::rhea:58850 (score: 0.4357)
# 10. Compound::CHEBI:37007 (score: 0.4352)
# 11. Compound::CHEBI:29449 (score: 0.4168)
# 12. Compound::CHEBI:15805 (score: 0.4123)
# 13. Compound::MESH:C400974 (score: 0.4014)
# 14. Compound::brenda:223261 (score: 0.3865)
# 15. Compound::MESH:C541773 (score: 0.3809)
# 16. Compound::pubchem:5287470 (score: 0.3773)
# 17. Compound::bindingdb:50154292 (score: 0.3736)
# 18. Compound::MESH:C037178 (score: 0.3616)
# 19. Compound::DB08431 (score: 0.3614)
# 20. Compound::MESH:C060090 (score: 0.3565)
#
# Disease::SARS-CoV2 M:
# 1. Compound::MESH:C555517 (score: 1.3289)
# 2. Compound::MESH:C060190 (score: 1.3186)
# 3. Compound::MESH:C082299 (score: 1.2848)
# 4. Compound::DB09512 (score: 1.1927)
# 5. Compound::MESH:C541335 (score: 1.1582)
# 6. Compound::CHEBI:30115 (score: 1.1245)
# 7. Compound::brenda:7493 (score: 1.1048)
# 8. Compound::DB15192 (score: 1.1027)
# 9. Compound::MESH:C017846 (score: 1.0842)
# 10. Compound::MESH:C040033 (score: 1.0799)
# 11. Compound::CHEMBL1200967 (score: 1.0728)
# 12. Compound::MESH:C022190 (score: 1.0483)
# 13. Compound::CHEMBL1178725 (score: 1.0384)
# 14. Compound::MESH:C559089 (score: 1.0323)
# 15. Compound::MESH:C074794 (score: 1.0319)
# 16. Compound::CHEMBL89093 (score: 1.0278)
# 17. Compound::MESH:C001526 (score: 1.0257)
# 18. Compound::CHEBI:64609 (score: 1.0211)
# 19. Compound::MESH:C059816 (score: 1.0015)
# 20. Compound::MESH:C413586 (score: 0.9990)
#
# Disease::SARS-CoV2 N:
# 1. Compound::brenda:224348 (score: 1.1885)
# 2. Compound::DB07652 (score: 1.0840)
# 3. Compound::brenda:169662 (score: 0.9694)
# 4. Compound::DB14017 (score: 0.9212)
# 5. Compound::brenda:80122 (score: 0.8720)
# 6. Compound::Bioarxivdrug:9 (score: 0.8589)
# 7. Compound::DB03896 (score: 0.8264)
# 8. Compound::CHEMBL2109592 (score: 0.7915)
# 9. Compound::CHEBI:15805 (score: 0.7877)
# 10. Compound::CHEBI:17234 (score: 0.7848)
# 11. Compound::DB02453 (score: 0.7845)
# 12. Compound::DB02506 (score: 0.7829)
# 13. Compound::DB02312 (score: 0.7738)
# 14. Compound::brenda:146844 (score: 0.7629)
# 15. Compound::bindingdb:50155929 (score: 0.7576)
# 16. Compound::CHEMBL2105734 (score: 0.7561)
# 17. Compound::pubchem:5287470 (score: 0.7523)
# 18. Compound::DB02370 (score: 0.7506)
# 19. Compound::MESH:C411294 (score: 0.7491)
# 20. Compound::CHEMBL2108712 (score: 0.7481)
#
# Disease::SARS-CoV2 Spike:
# 1. Compound::DB05819 (score: 1.1295)
# 2. Compound::DB00221 (score: 0.9060)
# 3. Compound::DB01554 (score: 0.8886)
# 4. Compound::MESH:C042354 (score: 0.8301)
# 5. Compound::DB11065 (score: 0.8035)
# 6. Compound::DB14638 (score: 0.7730)
# 7. Compound::MESH:D012103 (score: 0.7435)
# 8. Compound::MESH:C555517 (score: 0.7390)
# 9. Compound::MESH:C084378 (score: 0.7326)
# 10. Compound::DB06250 (score: 0.7321)
# 11. Compound::DB01434 (score: 0.7307)
# 12. Compound::MESH:D020682 (score: 0.7231)
# 13. Compound::DB09304 (score: 0.7222)
# 14. Compound::MESH:D055333 (score: 0.7175)
# 15. Compound::DB01521 (score: 0.7175)
# 16. Compound::DB01471 (score: 0.7083)
# 17. Compound::DB04688 (score: 0.6932)
# 18. Compound::DB01700 (score: 0.6896)
# 19. Compound::CHEBI:49159 (score: 0.6660)
# 20. Compound::MESH:C024873 (score: 0.6614)
#
# Disease::SARS-CoV2 nsp1:
# 1. Compound::DB12266 (score: 0.6252)
# 2. Compound::brenda:107533 (score: 0.6129)
# 3. Compound::brenda:80122 (score: 0.5698)
# 4. Compound::pubchem:984170 (score: 0.5511)
# 5. Compound::MESH:C411294 (score: 0.5478)
# 6. Compound::MESH:C089265 (score: 0.5403)
# 7. Compound::DB02506 (score: 0.5299)
# 8. Compound::brenda:224348 (score: 0.5205)
# 9. Compound::DB11470 (score: 0.5179)
# 10. Compound::DB08142 (score: 0.5139)
# 11. Compound::DB06836 (score: 0.5121)
# 12. Compound::DB13456 (score: 0.5113)
# 13. Compound::bindingdb:50139171 (score: 0.4855)
# 14. Compound::chebi:138488 (score: 0.4840)
# 15. Compound::MESH:C040507 (score: 0.4677)
# 16. Compound::DB11405 (score: 0.4596)
# 17. Compound::DB14810 (score: 0.4563)
# 18. Compound::brenda:146844 (score: 0.4523)
# 19. Compound::brenda:132269 (score: 0.4521)
# 20. Compound::pubchem:5287470 (score: 0.4504)
#
# Disease::SARS-CoV2 nsp10:
# 1. Compound::MESH:C555517 (score: 0.5810)
# 2. Compound::MESH:C488186 (score: 0.5105)
# 3. Compound::MESH:C060190 (score: 0.4652)
# 4. Compound::brenda:7493 (score: 0.4424)
# 5. Compound::MESH:C510385 (score: 0.4422)
# 6. Compound::DB03460 (score: 0.4288)
# 7. Compound::CHEBI:15805 (score: 0.4274)
# 8. Compound::MESH:C541938 (score: 0.4269)
# 9. Compound::MESH:C082299 (score: 0.4254)
# 10. Compound::CHEBI:62517 (score: 0.4162)
# 11. Compound::MESH:D013331 (score: 0.4149)
# 12. Compound::MESH:C073333 (score: 0.4128)
# 13. Compound::MESH:C041757 (score: 0.4124)
# 14. Compound::MESH:C000600930 (score: 0.4068)
# 15. Compound::MESH:C032175 (score: 0.4057)
# 16. Compound::MESH:C110174 (score: 0.4045)
# 17. Compound::MESH:D004376 (score: 0.3888)
# 18. Compound::MESH:C552597 (score: 0.3873)
# 19. Compound::MESH:C022190 (score: 0.3856)
# 20. Compound::pubchem:131704239 (score: 0.3850)
#
# Disease::SARS-CoV2 nsp11:
# 1. Compound::CHEBI:46765 (score: 1.6496)
# 2. Compound::MESH:C004600 (score: 1.3115)
# 3. Compound::MESH:C040738 (score: 1.2713)
# 4. Compound::MESH:C102786 (score: 1.2601)
# 5. Compound::DB14638 (score: 1.2378)
# 6. Compound::MESH:C020176 (score: 1.2255)
# 7. Compound::MESH:C037178 (score: 1.2011)
# 8. Compound::MESH:C105417 (score: 1.1894)
# 9. Compound::MESH:C004580 (score: 1.1856)
# 10. Compound::CHEBI:30049 (score: 1.1835)
# 11. Compound::MESH:C055632 (score: 1.1285)
# 12. Compound::MESH:C082299 (score: 1.1264)
# 13. Compound::MESH:C472007 (score: 1.0863)
# 14. Compound::MESH:D002506 (score: 1.0456)
# 15. Compound::CHEBI:29806 (score: 1.0401)
# 16. Compound::DB13960 (score: 1.0380)
# 17. Compound::MESH:C490727 (score: 1.0267)
# 18. Compound::pubchem:131704310 (score: 1.0259)
# 19. Compound::MESH:C119247 (score: 1.0118)
# 20. Compound::MESH:D055333 (score: 1.0082)
#
# Disease::SARS-CoV2 nsp12:
# 1. Compound::CHEMBL2109592 (score: 1.1588)
# 2. Compound::CHEBI:61050 (score: 1.0730)
# 3. Compound::MESH:C098250 (score: 1.0527)
# 4. Compound::CHEBI:15805 (score: 1.0522)
# 5. Compound::MESH:D003931 (score: 1.0200)
# 6. Compound::CHEMBL2108712 (score: 1.0001)
# 7. Compound::brenda:169662 (score: 0.9803)
# 8. Compound::MESH:C070070 (score: 0.9614)
# 9. Compound::DB02793 (score: 0.9490)
# 10. Compound::brenda:224348 (score: 0.9451)
# 11. Compound::MESH:D005070 (score: 0.9403)
# 12. Compound::MESH:D056572 (score: 0.9031)
# 13. Compound::DB07652 (score: 0.8973)
# 14. Compound::MESH:C032175 (score: 0.8708)
# 15. Compound::MESH:C011729 (score: 0.8675)
# 16. Compound::CHEBI:17234 (score: 0.8650)
# 17. Compound::CHEBI:30115 (score: 0.8633)
# 18. Compound::rhea:58100 (score: 0.8613)
# 19. Compound::DB02355 (score: 0.8516)
# 20. Compound::MESH:C040507 (score: 0.8452)
#
# Disease::SARS-CoV2 nsp13:
# 1. Compound::CHEMBL2109592 (score: 1.2566)
# 2. Compound::CHEMBL3707379 (score: 1.0418)
# 3. Compound::DB11922 (score: 1.0189)
# 4. Compound::brenda:220882 (score: 1.0101)
# 5. Compound::MESH:D003496 (score: 0.9812)
# 6. Compound::DB02057 (score: 0.9595)
# 7. Compound::DB02966 (score: 0.9581)
# 8. Compound::CHEMBL174356 (score: 0.9462)
# 9. Compound::MESH:C518328 (score: 0.9337)
# 10. Compound::MESH:C512397 (score: 0.9206)
# 11. Compound::DB01273 (score: 0.9015)
# 12. Compound::MESH:D009842 (score: 0.8901)
# 13. Compound::MESH:C006183 (score: 0.8828)
# 14. Compound::DB12135 (score: 0.8812)
# 15. Compound::DB02453 (score: 0.8768)
# 16. Compound::CHEMBL507824 (score: 0.8694)
# 17. Compound::CHEBI:61050 (score: 0.8693)
# 18. Compound::MESH:C081104 (score: 0.8682)
# 19. Compound::DB08535 (score: 0.8617)
# 20. Compound::MESH:C087567 (score: 0.8554)
#
# Disease::SARS-CoV2 nsp14:
# 1. Compound::brenda:223261 (score: 0.5452)
# 2. Compound::MESH:C042354 (score: 0.5392)
# 3. Compound::brenda:217865 (score: 0.4075)
# 4. Compound::DB09047 (score: 0.4044)
# 5. Compound::CHEMBL3349692 (score: 0.4016)
# 6. Compound::MESH:C013170 (score: 0.3870)
# 7. Compound::MESH:C084378 (score: 0.3769)
# 8. Compound::MESH:C024873 (score: 0.3525)
# 9. Compound::MESH:C077155 (score: 0.3519)
# 10. Compound::brenda:172539 (score: 0.3386)
# 11. Compound::brenda:12270 (score: 0.3379)
# 12. Compound::MESH:C007907 (score: 0.3361)
# 13. Compound::brenda:135439 (score: 0.3312)
# 14. Compound::MESH:C106426 (score: 0.3264)
# 15. Compound::DB14638 (score: 0.3211)
# 16. Compound::MESH:C079555 (score: 0.3166)
# 17. Compound::MESH:C043215 (score: 0.3163)
# 18. Compound::MESH:C508134 (score: 0.3124)
# 19. Compound::MESH:C487655 (score: 0.3058)
# 20. Compound::CHEMBL1200967 (score: 0.3021)
#
# Disease::SARS-CoV2 nsp15:
# 1. Compound::CHEMBL2109592 (score: 0.8242)
# 2. Compound::brenda:224348 (score: 0.6871)
# 3. Compound::CHEMBL3707379 (score: 0.5166)
# 4. Compound::brenda:217765 (score: 0.5153)
# 5. Compound::brenda:169662 (score: 0.4996)
# 6. Compound::Bioarxivdrug:9 (score: 0.4995)
# 7. Compound::DB03344 (score: 0.4779)
# 8. Compound::bindingdb:50154292 (score: 0.4591)
# 9. Compound::rhea:58772 (score: 0.4532)
# 10. Compound::zinc:ZINC000012504124 (score: 0.4507)
# 11. Compound::DB15595 (score: 0.4391)
# 12. Compound::CHEMBL2152332 (score: 0.4318)
# 13. Compound::DB02453 (score: 0.4270)
# 14. Compound::DB05070 (score: 0.4263)
# 15. Compound::brenda:220882 (score: 0.4217)
# 16. Compound::DB04998 (score: 0.4195)
# 17. Compound::DB01919 (score: 0.4122)
# 18. Compound::pubchem:5287470 (score: 0.4073)
# 19. Compound::DB05524 (score: 0.4012)
# 20. Compound::CHEMBL2109498 (score: 0.4008)
#
# Disease::SARS-CoV2 nsp2:
# 1. Compound::MESH:C082299 (score: 1.2589)
# 2. Compound::CHEBI:46765 (score: 1.1141)
# 3. Compound::DB11065 (score: 1.1113)
# 4. Compound::MESH:C073333 (score: 0.9840)
# 5. Compound::DB14638 (score: 0.9677)
# 6. Compound::MESH:C020176 (score: 0.9655)
# 7. Compound::MESH:C555517 (score: 0.8758)
# 8. Compound::MESH:C055632 (score: 0.8747)
# 9. Compound::MESH:D010402 (score: 0.8637)
# 10. Compound::CHEBI:30115 (score: 0.8533)
# 11. Compound::MESH:C040033 (score: 0.8441)
# 12. Compound::MESH:C102786 (score: 0.8211)
# 13. Compound::DB10716 (score: 0.8111)
# 14. Compound::MESH:C040738 (score: 0.7818)
# 15. Compound::MESH:D020682 (score: 0.7700)
# 16. Compound::MESH:D005070 (score: 0.7608)
# 17. Compound::MESH:C004580 (score: 0.7500)
# 18. Compound::MESH:C084588 (score: 0.7407)
# 19. Compound::MESH:C064270 (score: 0.7340)
# 20. Compound::MESH:C060190 (score: 0.7316)
#
# Disease::SARS-CoV2 nsp4:
# 1. Compound::DB11065 (score: 0.6865)
# 2. Compound::MESH:C070070 (score: 0.6362)
# 3. Compound::MESH:C555517 (score: 0.5678)
# 4. Compound::MESH:C082299 (score: 0.5545)
# 5. Compound::DB06379 (score: 0.5493)
# 6. Compound::brenda:224348 (score: 0.5154)
# 7. Compound::CHEMBL2158051 (score: 0.5148)
# 8. Compound::CHEMBL3108827 (score: 0.5148)
# 9. Compound::MESH:D056572 (score: 0.5019)
# 10. Compound::DB11782 (score: 0.5018)
# 11. Compound::DB14638 (score: 0.4900)
# 12. Compound::brenda:7493 (score: 0.4827)
# 13. Compound::MESH:C073333 (score: 0.4824)
# 14. Compound::DB10716 (score: 0.4756)
# 15. Compound::CHEMBL504559 (score: 0.4696)
# 16. Compound::MESH:C020176 (score: 0.4553)
# 17. Compound::Bioarxivdrug:9 (score: 0.4510)
# 18. Compound::MESH:C016957 (score: 0.4431)
# 19. Compound::MESH:C552597 (score: 0.4428)
# 20. Compound::MESH:C488186 (score: 0.4278)
#
# Disease::SARS-CoV2 nsp5:
# 1. Compound::CHEMBL2109592 (score: 0.8643)
# 2. Compound::DB02506 (score: 0.5944)
# 3. Compound::DB08248 (score: 0.5510)
# 4. Compound::molport:MolPort-046-763-600 (score: 0.5313)
# 5. Compound::DB07652 (score: 0.5294)
# 6. Compound::brenda:80122 (score: 0.5179)
# 7. Compound::brenda:224348 (score: 0.4865)
# 8. Compound::DB15131 (score: 0.4804)
# 9. Compound::brenda:9900 (score: 0.4672)
# 10. Compound::DB14581 (score: 0.4544)
# 11. Compound::bindingdb:50155929 (score: 0.4537)
# 12. Compound::brenda:135439 (score: 0.4529)
# 13. Compound::DB07431 (score: 0.4495)
# 14. Compound::DB02453 (score: 0.4453)
# 15. Compound::brenda:169662 (score: 0.4435)
# 16. Compound::molport:MolPort-046-690-277 (score: 0.4393)
# 17. Compound::bindingdb:50139171 (score: 0.4331)
# 18. Compound::DB14999 (score: 0.4269)
# 19. Compound::MESH:C022146 (score: 0.4019)
# 20. Compound::Bioarxivdrug:9 (score: 0.3978)
#
# Disease::SARS-CoV2 nsp5_C145A:
# 1. Compound::MESH:C551241 (score: 0.3091)
# 2. Compound::MESH:C000600963 (score: 0.2502)
# 3. Compound::brenda:12270 (score: 0.2423)
# 4. Compound::molport:MolPort-006-111-226 (score: 0.2389)
# 5. Compound::MESH:C000594652 (score: 0.2266)
# 6. Compound::MESH:C544835 (score: 0.2173)
# 7. Compound::DB12282 (score: 0.2092)
# 8. Compound::DB11861 (score: 0.2000)
# 9. Compound::MESH:C475622 (score: 0.1974)
# 10. Compound::DB14973 (score: 0.1974)
# 11. Compound::MESH:C550248 (score: 0.1911)
# 12. Compound::MESH:C535156 (score: 0.1872)
# 13. Compound::DB15445 (score: 0.1851)
# 14. Compound::CHEMBL2164243 (score: 0.1802)
# 15. Compound::MESH:C573150 (score: 0.1797)
# 16. Compound::DB05364 (score: 0.1789)
# 17. Compound::DB15047 (score: 0.1742)
# 18. Compound::MESH:C003724 (score: 0.1741)
# 19. Compound::MESH:C000592454 (score: 0.1732)
# 20. Compound::MESH:C570895 (score: 0.1686)
#
# Disease::SARS-CoV2 nsp6:
# 1. Compound::MESH:C082299 (score: 0.8742)
# 2. Compound::MESH:C541335 (score: 0.7948)
# 3. Compound::brenda:7493 (score: 0.7252)
# 4. Compound::MESH:D001950 (score: 0.7240)
# 5. Compound::MESH:C060190 (score: 0.6394)
# 6. Compound::DB09512 (score: 0.6314)
# 7. Compound::CHEBI:64609 (score: 0.6076)
# 8. Compound::MESH:C033689 (score: 0.5976)
# 9. Compound::MESH:C440193 (score: 0.5854)
# 10. Compound::MESH:C010402 (score: 0.5634)
# 11. Compound::MESH:C051402 (score: 0.5548)
# 12. Compound::MESH:C050877 (score: 0.5447)
# 13. Compound::MESH:C018273 (score: 0.5309)
# 14. Compound::MESH:C059816 (score: 0.5271)
# 15. Compound::MESH:C118657 (score: 0.5189)
# 16. Compound::MESH:C413586 (score: 0.5179)
# 17. Compound::MESH:C017846 (score: 0.5141)
# 18. Compound::MESH:C034130 (score: 0.5099)
# 19. Compound::MESH:C041757 (score: 0.5019)
# 20. Compound::MESH:C478108 (score: 0.4996)
#
# Disease::SARS-CoV2 nsp7:
# 1. Compound::MESH:C082299 (score: 1.4040)
# 2. Compound::MESH:C060190 (score: 1.3543)
# 3. Compound::MESH:C034177 (score: 1.3436)
# 4. Compound::MESH:C001526 (score: 1.3015)
# 5. Compound::MESH:C555517 (score: 1.2906)
# 6. Compound::MESH:C040033 (score: 1.1894)
# 7. Compound::DB08956 (score: 1.1794)
# 8. Compound::MESH:C034130 (score: 1.1786)
# 9. Compound::DB06379 (score: 1.1768)
# 10. Compound::MESH:C017846 (score: 1.1757)
# 11. Compound::MESH:C541335 (score: 1.1746)
# 12. Compound::DB09512 (score: 1.1426)
# 13. Compound::MESH:C059816 (score: 1.1194)
# 14. Compound::MESH:C413586 (score: 1.1019)
# 15. Compound::MESH:C084588 (score: 1.1017)
# 16. Compound::CHEBI:64609 (score: 1.0745)
# 17. Compound::CHEBI:6549 (score: 1.0686)
# 18. Compound::CHEBI:30115 (score: 1.0497)
# 19. Compound::MESH:C051402 (score: 1.0324)
# 20. Compound::MESH:C106426 (score: 1.0270)
#
# Disease::SARS-CoV2 nsp8:
# 1. Compound::MESH:C082299 (score: 1.8334)
# 2. Compound::DB11065 (score: 1.7003)
# 3. Compound::MESH:C020176 (score: 1.5308)
# 4. Compound::MESH:C559761 (score: 1.5084)
# 5. Compound::MESH:C555517 (score: 1.4028)
# 6. Compound::DB08602 (score: 1.2279)
# 7. Compound::CHEBI:30115 (score: 1.2070)
# 8. Compound::MESH:C070070 (score: 1.1979)
# 9. Compound::MESH:C074794 (score: 1.1898)
# 10. Compound::CHEMBL329722 (score: 1.1757)
# 11. Compound::MESH:C033689 (score: 1.1594)
# 12. Compound::MESH:C040033 (score: 1.1560)
# 13. Compound::DB14638 (score: 1.1479)
# 14. Compound::MESH:C073333 (score: 1.1269)
# 15. Compound::MESH:D005070 (score: 1.1030)
# 16. Compound::DB00085 (score: 1.0926)
# 17. Compound::CHEMBL37860 (score: 1.0911)
# 18. Compound::MESH:C004600 (score: 1.0735)
# 19. Compound::DB02736 (score: 1.0684)
# 20. Compound::CHEMBL52422 (score: 1.0616)
#
# Disease::SARS-CoV2 nsp9:
# 1. Compound::MESH:C102786 (score: 0.9885)
# 2. Compound::DB14093 (score: 0.9105)
# 3. Compound::MESH:C004580 (score: 0.8974)
# 4. Compound::DB11668 (score: 0.8742)
# 5. Compound::CHEBI:29389 (score: 0.7906)
# 6. Compound::CHEMBL2108712 (score: 0.7905)
# 7. Compound::MESH:C578687 (score: 0.7279)
# 8. Compound::DB11394 (score: 0.6803)
# 9. Compound::DB12909 (score: 0.6776)
# 10. Compound::MESH:C076253 (score: 0.6758)
# 11. Compound::DB14638 (score: 0.6737)
# 12. Compound::MESH:C004600 (score: 0.6702)
# 13. Compound::brenda:135439 (score: 0.6639)
# 14. Compound::MESH:C518545 (score: 0.6619)
# 15. Compound::CHEBI:46765 (score: 0.6593)
# 16. Compound::CHEBI:29806 (score: 0.6553)
# 17. Compound::MESH:D010402 (score: 0.6527)
# 18. Compound::brenda:223261 (score: 0.6417)
# 19. Compound::brenda:169662 (score: 0.6390)
# 20. Compound::MESH:C487655 (score: 0.6210)
#
# Disease::SARS-CoV2 orf10:
# 1. Compound::brenda:224348 (score: 1.3420)
# 2. Compound::CHEMBL2109592 (score: 1.0986)
# 3. Compound::Bioarxivdrug:9 (score: 1.0161)
# 4. Compound::bindingdb:50139171 (score: 0.9741)
# 5. Compound::DB02453 (score: 0.9696)
# 6. Compound::brenda:42410 (score: 0.9427)
# 7. Compound::DB11782 (score: 0.8906)
# 8. Compound::DB14017 (score: 0.8793)
# 9. Compound::brenda:80122 (score: 0.8738)
# 10. Compound::CHEMBL2109393 (score: 0.8705)
# 11. Compound::DB07652 (score: 0.8658)
# 12. Compound::DB04998 (score: 0.8080)
# 13. Compound::brenda:169662 (score: 0.8066)
# 14. Compound::brenda:21576 (score: 0.7842)
# 15. Compound::brenda:220871 (score: 0.7787)
# 16. Compound::DB12380 (score: 0.7781)
# 17. Compound::rhea:58100 (score: 0.7689)
# 18. Compound::CHEMBL2105734 (score: 0.7582)
# 19. Compound::brenda:65351 (score: 0.7515)
# 20. Compound::CHEMBL481422 (score: 0.7475)
#
# Disease::SARS-CoV2 orf3a:
# 1. Compound::MESH:C082299 (score: 0.6922)
# 2. Compound::MESH:C070070 (score: 0.6654)
# 3. Compound::MESH:C074794 (score: 0.5814)
# 4. Compound::DB15120 (score: 0.5433)
# 5. Compound::DB08956 (score: 0.5137)
# 6. Compound::CHEMBL1627081 (score: 0.4936)
# 7. Compound::MESH:C073333 (score: 0.4930)
# 8. Compound::MESH:C041269 (score: 0.4893)
# 9. Compound::MESH:C034177 (score: 0.4793)
# 10. Compound::DB06379 (score: 0.4792)
# 11. Compound::CHEMBL2158051 (score: 0.4766)
# 12. Compound::MESH:D001950 (score: 0.4751)
# 13. Compound::MESH:C051402 (score: 0.4721)
# 14. Compound::MESH:C555517 (score: 0.4710)
# 15. Compound::MESH:C040033 (score: 0.4689)
# 16. Compound::MESH:C020445 (score: 0.4673)
# 17. Compound::MESH:C101628 (score: 0.4658)
# 18. Compound::CHEMBL3108827 (score: 0.4649)
# 19. Compound::DB03024 (score: 0.4641)
# 20. Compound::DB11782 (score: 0.4640)
#
# Disease::SARS-CoV2 orf3b:
# 1. Compound::CHEBI:15805 (score: 0.6314)
# 2. Compound::MESH:C541938 (score: 0.6086)
# 3. Compound::CHEMBL2158051 (score: 0.6011)
# 4. Compound::MESH:C508134 (score: 0.6006)
# 5. Compound::brenda:7493 (score: 0.5463)
# 6. Compound::MESH:C488186 (score: 0.5236)
# 7. Compound::CHEMBL332347 (score: 0.4980)
# 8. Compound::DB11065 (score: 0.4968)
# 9. Compound::MESH:C073333 (score: 0.4895)
# 10. Compound::MESH:C016957 (score: 0.4847)
# 11. Compound::MESH:D005291 (score: 0.4657)
# 12. Compound::CHEMBL504559 (score: 0.4647)
# 13. Compound::MESH:C082299 (score: 0.4636)
# 14. Compound::CHEBI:51973 (score: 0.4583)
# 15. Compound::CHEBI:51451 (score: 0.4484)
# 16. Compound::DB08602 (score: 0.4471)
# 17. Compound::brenda:169662 (score: 0.4442)
# 18. Compound::MESH:C440193 (score: 0.4422)
# 19. Compound::CHEMBL3108827 (score: 0.4419)
# 20. Compound::DB03911 (score: 0.4363)
#
# Disease::SARS-CoV2 orf6:
# 1. Compound::brenda:224348 (score: 0.6984)
# 2. Compound::brenda:7493 (score: 0.6836)
# 3. Compound::brenda:169662 (score: 0.5793)
# 4. Compound::MESH:C541938 (score: 0.5417)
# 5. Compound::Bioarxivdrug:9 (score: 0.5164)
# 6. Compound::pubchem:5287470 (score: 0.5038)
# 7. Compound::DB11782 (score: 0.5026)
# 8. Compound::DB08535 (score: 0.4798)
# 9. Compound::MESH:C488186 (score: 0.4772)
# 10. Compound::brenda:80122 (score: 0.4600)
# 11. Compound::CHEMBL2105734 (score: 0.4546)
# 12. Compound::CHEMBL3220918 (score: 0.4407)
# 13. Compound::MESH:C055018 (score: 0.4346)
# 14. Compound::brenda:65351 (score: 0.4308)
# 15. Compound::pubchem:984170 (score: 0.4294)
# 16. Compound::MESH:C440193 (score: 0.4211)
# 17. Compound::DB11922 (score: 0.4189)
# 18. Compound::CHEMBL2158051 (score: 0.4172)
# 19. Compound::zinc:ZINC000012504124 (score: 0.4170)
# 20. Compound::rhea:58100 (score: 0.4105)
#
# Disease::SARS-CoV2 orf7a:
# 1. Compound::MESH:C102786 (score: 1.9035)
# 2. Compound::DB01044 (score: 1.7442)
# 3. Compound::MESH:C004580 (score: 1.5690)
# 4. Compound::MESH:C004600 (score: 1.5475)
# 5. Compound::MESH:C020176 (score: 1.3393)
# 6. Compound::CHEBI:29806 (score: 1.3247)
# 7. Compound::MESH:C082299 (score: 1.3220)
# 8. Compound::DB11065 (score: 1.2887)
# 9. Compound::MESH:D055333 (score: 1.2854)
# 10. Compound::MESH:C105417 (score: 1.2755)
# 11. Compound::CHEBI:46765 (score: 1.2580)
# 12. Compound::DB14638 (score: 1.2519)
# 13. Compound::CHEBI:30049 (score: 1.2335)
# 14. Compound::DB04580 (score: 1.2323)
# 15. Compound::DB00766 (score: 1.2180)
# 16. Compound::MESH:C043065 (score: 1.2059)
# 17. Compound::DB00400 (score: 1.1683)
# 18. Compound::CHEMBL2108730 (score: 1.1511)
# 19. Compound::MESH:C006739 (score: 1.1400)
# 20. Compound::DB14035 (score: 1.1365)
#
# Disease::SARS-CoV2 orf8:
# 1. Compound::brenda:135439 (score: 1.2373)
# 2. Compound::MESH:C024873 (score: 1.2231)
# 3. Compound::DB14638 (score: 1.1491)
# 4. Compound::MESH:C555517 (score: 1.1066)
# 5. Compound::MESH:C033689 (score: 1.1038)
# 6. Compound::brenda:223261 (score: 1.0893)
# 7. Compound::MESH:C040033 (score: 1.0870)
# 8. Compound::MESH:C020176 (score: 1.0766)
# 9. Compound::MESH:C073333 (score: 0.9915)
# 10. Compound::DB11065 (score: 0.9713)
# 11. Compound::MESH:C106426 (score: 0.9704)
# 12. Compound::MESH:C046651 (score: 0.9448)
# 13. Compound::MESH:C021151 (score: 0.9261)
# 14. Compound::DB05683 (score: 0.9063)
# 15. Compound::MESH:C400974 (score: 0.9042)
# 16. Compound::MESH:D010402 (score: 0.9012)
# 17. Compound::MESH:C082299 (score: 0.9010)
# 18. Compound::MESH:C448680 (score: 0.8801)
# 19. Compound::CHEMBL2108712 (score: 0.8771)
# 20. Compound::MESH:C055632 (score: 0.8603)
#
# Disease::SARS-CoV2 orf9b:
# 1. Compound::brenda:224348 (score: 0.5236)
# 2. Compound::MESH:C084813 (score: 0.5115)
# 3. Compound::CHEMBL2109592 (score: 0.5095)
# 4. Compound::MESH:C032175 (score: 0.5067)
# 5. Compound::DB02966 (score: 0.4900)
# 6. Compound::CHEBI:15805 (score: 0.4884)
# 7. Compound::pubchem:131704239 (score: 0.4625)
# 8. Compound::brenda:7493 (score: 0.4573)
# 9. Compound::MESH:C510385 (score: 0.4523)
# 10. Compound::CHEMBL1200703 (score: 0.4520)
# 11. Compound::MESH:C488186 (score: 0.4420)
# 12. Compound::MESH:C512397 (score: 0.4411)
# 13. Compound::MESH:C040507 (score: 0.4384)
# 14. Compound::CHEBI:17234 (score: 0.4318)
# 15. Compound::CHEMBL2109500 (score: 0.4298)
# 16. Compound::pubchem:131704263 (score: 0.4156)
# 17. Compound::brenda:220882 (score: 0.4055)
# 18. Compound::MESH:D003496 (score: 0.4007)
# 19. Compound::CHEMBL2109498 (score: 0.3955)
# 20. Compound::MESH:C016957 (score: 0.3846)
#
# Disease::SARS-CoV2 orf9c:
# 1. Compound::MESH:C082299 (score: 1.5409)
# 2. Compound::DB14638 (score: 1.4082)
# 3. Compound::MESH:C555517 (score: 1.3351)
# 4. Compound::MESH:C020176 (score: 1.3281)
# 5. Compound::DB11065 (score: 1.3269)
# 6. Compound::DB09512 (score: 1.3008)
# 7. Compound::MESH:C040033 (score: 1.2770)
# 8. Compound::MESH:C024873 (score: 1.2729)
# 9. Compound::MESH:D020682 (score: 1.2240)
# 10. Compound::MESH:C055632 (score: 1.2144)
# 11. Compound::MESH:C033689 (score: 1.2056)
# 12. Compound::MESH:C063378 (score: 1.1207)
# 13. Compound::CHEBI:46765 (score: 1.0999)
# 14. Compound::MESH:C583128 (score: 1.0857)
# 15. Compound::MESH:C032294 (score: 1.0766)
# 16. Compound::MESH:C042354 (score: 1.0765)
# 17. Compound::MESH:C559761 (score: 1.0651)
# 18. Compound::MESH:C021151 (score: 1.0626)
# 19. Compound::DB15192 (score: 1.0489)
# 20. Compound::MESH:C080362 (score: 1.0395)
#
# Disease::MESH:D045169:
# 1. Compound::DB00811 (score: 5.9587)
# 2. Compound::DB09140 (score: 5.8429)
# 3. Compound::DB00415 (score: 5.6118)
# 4. Compound::DB00759 (score: 5.5113)
# 5. Compound::DB01593 (score: 5.4121)
# 6. Compound::DB01592 (score: 5.2351)
# 7. Compound::MESH:D013256 (score: 5.1342)
# 8. Compound::MESH:D010406 (score: 5.0784)
# 9. Compound::DB00982 (score: 5.0430)
# 10. Compound::DB00741 (score: 5.0115)
# 11. Compound::DB01212 (score: 4.9210)
# 12. Compound::DB00860 (score: 4.8528)
# 13. Compound::CHEBI:35341 (score: 4.8487)
# 14. Compound::DB00787 (score: 4.7618)
# 15. Compound::DB00165 (score: 4.7339)
# 16. Compound::DB03461 (score: 4.7256)
# 17. Compound::DB00563 (score: 4.7168)
# 18. Compound::DB00446 (score: 4.6928)
# 19. Compound::DB00331 (score: 4.6726)
# 20. Compound::DB00512 (score: 4.6547)
#
# Disease::MESH:D045473:
# 1. Compound::DB00190 (score: 1.1978)
# 2. Compound::CHEMBL2012938 (score: 1.1291)
# 3. Compound::DB11944 (score: 1.1120)
# 4. Compound::DB00689 (score: 1.1079)
# 5. Compound::DB05532 (score: 1.0364)
# 6. Compound::brenda:169662 (score: 1.0206)
# 7. Compound::CHEMBL1631540 (score: 1.0198)
# 8. Compound::CHEMBL2158051 (score: 0.9794)
# 9. Compound::DB12791 (score: 0.9423)
# 10. Compound::DB01111 (score: 0.9305)
# 11. Compound::CHEMBL504559 (score: 0.9191)
# 12. Compound::bindingdb:50154292 (score: 0.8965)
# 13. Compound::DB09111 (score: 0.8925)
# 14. Compound::DB02304 (score: 0.8877)
# 15. Compound::CHEMBL3108827 (score: 0.8864)
# 16. Compound::MESH:C584311 (score: 0.8808)
# 17. Compound::DB00438 (score: 0.8669)
# 18. Compound::DB12753 (score: 0.8639)
# 19. Compound::DB00369 (score: 0.8526)
# 20. Compound::DB01428 (score: 0.8511)
#
# Disease::MESH:D001351:
# 1. Compound::CHEMBL1631540 (score: 1.1332)
# 2. Compound::DB12925 (score: 1.1230)
# 3. Compound::CHEMBL2096742 (score: 1.0168)
# 4. Compound::CHEMBL520107 (score: 1.0070)
# 5. Compound::CHEMBL188528 (score: 0.9845)
# 6. Compound::CHEMBL10041 (score: 0.9630)
# 7. Compound::DB04851 (score: 0.9519)
# 8. Compound::CHEMBL379787 (score: 0.9476)
# 9. Compound::CHEMBL13378 (score: 0.9468)
# 10. Compound::DB11944 (score: 0.9362)
# 11. Compound::DB04877 (score: 0.8927)
# 12. Compound::DB02966 (score: 0.8828)
# 13. Compound::MESH:C584311 (score: 0.8629)
# 14. Compound::CHEMBL1207366 (score: 0.8539)
# 15. Compound::MESH:C041069 (score: 0.8521)
# 16. Compound::CHEMBL222519 (score: 0.8517)
# 17. Compound::brenda:42126 (score: 0.8342)
# 18. Compound::CHEMBL3545411 (score: 0.8285)
# 19. Compound::DB04900 (score: 0.8261)
# 20. Compound::CHEMBL2107387 (score: 0.8033)
#
# Disease::MESH:D065207:
# 1. Compound::CHEMBL39071 (score: 0.6175)
# 2. Compound::CHEMBL34155 (score: 0.5543)
# 3. Compound::CHEMBL3707402 (score: 0.5472)
# 4. Compound::DB12005 (score: 0.5021)
# 5. Compound::brenda:7493 (score: 0.4749)
# 6. Compound::CHEMBL3707250 (score: 0.4469)
# 7. Compound::molport:MolPort-046-426-188 (score: 0.4400)
# 8. Compound::DB02853 (score: 0.4349)
# 9. Compound::CHEMBL280828 (score: 0.4260)
# 10. Compound::brenda:63562 (score: 0.3897)
# 11. Compound::CHEMBL4297422 (score: 0.3851)
# 12. Compound::CHEMBL2024567 (score: 0.3800)
# 13. Compound::CHEMBL275040 (score: 0.3783)
# 14. Compound::CHEBI:18038 (score: 0.3750)
# 15. Compound::MESH:C045038 (score: 0.3696)
# 16. Compound::DB05458 (score: 0.3505)
# 17. Compound::CHEMBL6623 (score: 0.3472)
# 18. Compound::CHEMBL1200538 (score: 0.3465)
# 19. Compound::bindingdb:50190109 (score: 0.3411)
# 20. Compound::brenda:70387 (score: 0.3408)
#
# Disease::MESH:D028941:
# 1. Compound::DB00547 (score: 1.0409)
# 2. Compound::DB00873 (score: 1.0013)
# 3. Compound::CHEMBL3186227 (score: 0.9932)
# 4. Compound::DB00687 (score: 0.9806)
# 5. Compound::DB00596 (score: 0.8537)
# 6. Compound::DB11079 (score: 0.8176)
# 7. Compound::DB02546 (score: 0.8139)
# 8. Compound::DB04914 (score: 0.7872)
# 9. Compound::DB12461 (score: 0.7344)
# 10. Compound::DB06786 (score: 0.7227)
# 11. Compound::DB06807 (score: 0.7121)
# 12. Compound::DB06781 (score: 0.7084)
# 13. Compound::DB11389 (score: 0.7027)
# 14. Compound::DB11464 (score: 0.6968)
# 15. Compound::DB12921 (score: 0.6919)
# 16. Compound::DB00223 (score: 0.6775)
# 17. Compound::DB00324 (score: 0.6716)
# 18. Compound::DB12686 (score: 0.6649)
# 19. Compound::DB13485 (score: 0.6464)
# 20. Compound::DB00838 (score: 0.6378)
#
# Disease::MESH:D058957:
# 1. Compound::MESH:C082299 (score: 0.5377)
# 2. Compound::CHEMBL3707379 (score: 0.4571)
# 3. Compound::MESH:C024524 (score: 0.3973)
# 4. Compound::brenda:7493 (score: 0.3927)
# 5. Compound::MESH:C440193 (score: 0.3690)
# 6. Compound::DB08848 (score: 0.3632)
# 7. Compound::MESH:C009936 (score: 0.3381)
# 8. Compound::CHEMBL2012938 (score: 0.3319)
# 9. Compound::CHEMBL1200982 (score: 0.3140)
# 10. Compound::MESH:C098250 (score: 0.2987)
# 11. Compound::DB03344 (score: 0.2877)
# 12. Compound::CHEMBL738 (score: 0.2869)
# 13. Compound::DB05432 (score: 0.2861)
# 14. Compound::DB13353 (score: 0.2780)
# 15. Compound::pubchem:5287469 (score: 0.2732)
# 16. Compound::DB04991 (score: 0.2659)
# 17. Compound::MESH:C115705 (score: 0.2640)
# 18. Compound::MESH:C046285 (score: 0.2639)
# 19. Compound::CHEMBL1200703 (score: 0.2574)
# 20. Compound::CHEMBL1200903 (score: 0.2544)
#
# Disease::MESH:D006517:
# 1. Compound::CHEMBL1631540 (score: 1.3840)
# 2. Compound::CHEMBL520107 (score: 1.1998)
# 3. Compound::DB12925 (score: 1.1450)
# 4. Compound::CHEMBL188528 (score: 1.1173)
# 5. Compound::CHEMBL3545408 (score: 1.0590)
# 6. Compound::CHEMBL3235279 (score: 1.0487)
# 7. Compound::CHEMBL39071 (score: 1.0093)
# 8. Compound::CHEMBL3707402 (score: 0.9902)
# 9. Compound::CHEMBL1200538 (score: 0.9674)
# 10. Compound::brenda:16029 (score: 0.9650)
# 11. Compound::CHEMBL219182 (score: 0.9626)
# 12. Compound::DB07423 (score: 0.9566)
# 13. Compound::MESH:C584311 (score: 0.9428)
# 14. Compound::DB06579 (score: 0.9335)
# 15. Compound::CHEMBL1200980 (score: 0.9335)
# 16. Compound::brenda:67384 (score: 0.9313)
# 17. Compound::CHEMBL3545411 (score: 0.9288)
# 18. Compound::CHEMBL3544957 (score: 0.9262)
# 19. Compound::DB02966 (score: 0.9171)
# 20. Compound::CHEMBL3545230 (score: 0.9153)

# %%
def get_compounds_with_treatments(graph):
    """
    Get list of compounds that have treatment data associated with COVID-19.
    Returns list of compounds and count.
    """
    # Initialize an empty list to store compound nodes.
    compounds = []

    # Iterate through all nodes and their attributes.
    for node, attributes in graph.nodes(data=True):
        # Check if the node is a string, starts with 'Compound::', and contains 'treatment_data' in its attributes.
        if (isinstance(node, str) and
            node.startswith('Compound::') and
            'treatment_data' in attributes):
            compounds.append(node)

    return compounds, len(compounds)

# Get the compounds and count
compounds, num_compounds = get_compounds_with_treatments(graph)
print(compounds)
print(num_compounds)
# Out:
# ['Compound::DB01087', 'Compound::DB01072', 'Compound::DB06817', 'Compound::DB00773', 'Compound::DB01392', 'Compound::DB00539', 'Compound::DB07795', 'Compound::DB13997', 'Compound::DB09299', 'Compound::DB00608', 'Compound::DB14126', 'Compound::DB00091', 'Compound::DB00198', 'Compound::DB00811', 'Compound::DB09026', 'Compound::DB08934', 'Compound::DB00220', 'Compound::DB11779', 'Compound::DB00328', 'Compound::DB04786', 'Compound::DB00482', 'Compound::DB01015', 'Compound::DB09102', 'Compound::DB01264', 'Compound::DB01645', 'Compound::DB00822', 'Compound::DB09065', 'Compound::DB12610', 'Compound::DB00831', 'Compound::DB00457', 'Compound::DB04115', 'Compound::DB01041', 'Compound::DB00722', 'Compound::DB00213', 'Compound::DB00133', 'Compound::DB06803', 'Compound::DB12270', 'Compound::DB00319', 'Compound::DB11952', 'Compound::DB00302', 'Compound::DB00199', 'Compound::DB13925', 'Compound::DB00143', 'Compound::DB09061', 'Compound::DB14810', 'Compound::DB00673', 'Compound::DB00159', 'Compound::DB00966', 'Compound::DB01190', 'Compound::DB04224', 'Compound::DB11859', 'Compound::DB08868', 'Compound::DB06699', 'Compound::DB09322', 'Compound::DB00146', 'Compound::DB06210', 'Compound::DB11758', 'Compound::DB00140', 'Compound::DB01075', 'Compound::DB04862', 'Compound::DB01262', 'Compound::DB00881', 'Compound::DB00855', 'Compound::DB01430', 'Compound::DB06605', 'Compound::DB00151', 'Compound::DB00316', 'Compound::DB00126', 'Compound::DB00569', 'Compound::DB01410', 'Compound::DB12582', 'Compound::DB01042', 'Compound::DB00471', 'Compound::DB00264', 'Compound::DB00281', 'Compound::DB00507', 'Compound::DB11697', 'Compound::DB00920', 'Compound::DB01390', 'Compound::DB01029', 'Compound::DB02701', 'Compound::DB00848', 'Compound::DB00480', 'Compound::DB00825', 'Compound::DB01088', 'Compound::DB01050', 'Compound::DB00477', 'Compound::DB01115', 'Compound::DB00761', 'Compound::DB06209', 'Compound::DB06403', 'Compound::DB15446', 'Compound::DB00758', 'Compound::DB08882', 'Compound::DB04977', 'Compound::DB00006', 'Compound::DB06228', 'Compound::DB12580', 'Compound::DB04951', 'Compound::DB00278', 'Compound::DB01126', 'Compound::DB12668', 'Compound::DB00691', 'Compound::DB11863', 'Compound::DB00980', 'Compound::DB00783', 'Compound::DB00945', 'Compound::DB12614', 'Compound::DB01234', 'Compound::DB00806', 'Compound::DB01118', 'Compound::DB01060', 'Compound::DB06151', 'Compound::DB09241', 'Compound::DB06280', 'Compound::DB09154', 'Compound::DB11651', 'Compound::DB05676', 'Compound::DB01197', 'Compound::DB06515', 'Compound::DB00818', 'Compound::DB00877', 'Compound::DB00878', 'Compound::DB00155', 'Compound::DB05076', 'Compound::DB11720', 'Compound::DB01076', 'Compound::DB00169', 'Compound::DB00704', 'Compound::DB00982', 'Compound::DB00755', 'Compound::DB00661', 'Compound::DB00338', 'Compound::DB11817', 'Compound::DB00472', 'Compound::DB06717', 'Compound::DB01137', 'Compound::DB01212', 'Compound::DB00683', 'Compound::DB00313', 'Compound::DB15035', 'Compound::DB00542', 'Compound::DB00177', 'Compound::DB01222', 'Compound::DB00613', 'Compound::DB11574', 'Compound::DB09053', 'Compound::DB00796', 'Compound::DB09112', 'Compound::DB09130', 'Compound::DB00788', 'Compound::DB00435', 'Compound::DB05511', 'Compound::DB01039', 'Compound::DB11590', 'Compound::DB09019', 'Compound::DB00741', 'Compound::DB12612', 'Compound::DB00396', 'Compound::DB12010', 'Compound::DB08822', 'Compound::DB04854', 'Compound::DB00653', 'Compound::DB11526', 'Compound::DB01593', 'Compound::DB00497', 'Compound::DB00148', 'Compound::DB00121', 'Compound::DB00178', 'Compound::DB08995', 'Compound::DB03904', 'Compound::DB01216', 'Compound::DB13729', 'Compound::DB00519', 'Compound::DB04743', 'Compound::DB01132', 'Compound::DB01065', 'Compound::DB01236', 'Compound::DB00753', 'Compound::DB01240', 'Compound::DB09075', 'Compound::DB00916', 'Compound::DB00203', 'Compound::DB00583', 'Compound::DB04835', 'Compound::DB00176', 'Compound::DB05266', 'Compound::DB00864', 'Compound::DB00275', 'Compound::DB01394', 'Compound ...
# 451

# %%
def analyze_predictions_vs_treatments(predictions, actual_compounds):
    """
    Analyze how many predicted compounds for each disease are actual treatment compounds.
    """
    analysis_results = {}

    # Loop through all predicted compounds and respective diseases
    for disease, predicted_compounds in predictions.items():
        if predicted_compounds:
            # Get just the compound names from predictions (without scores)
            predicted_set = set(compound for compound, _ in predicted_compounds)

            # Find overlap with actual compounds
            overlap = predicted_set.intersection(set(actual_compounds))

            # Calculate percentage
            percentage = (len(overlap) / len(predicted_compounds)) * 100

            # Store results
            analysis_results[disease] = {
                'overlap_count': len(overlap),
                'overlap_percentage': percentage,
                'overlapping_compounds': list(overlap)
            }

            # Print results
            print(f"\n{disease}:")
            print(f"Number of predicted compounds in treatment database: {len(overlap)}/20")
            print(f"Percentage: {percentage:.2f}%")
            print("Overlapping compounds:")
            for compound in overlap:
                print(f"- {compound}")

    return analysis_results

# First get predictions
relation = "DRKG::Treats::Compound:Disease"
predictions = get_top_predictions(
    result.model,
    train_factory,
    relation,
    COV_disease_list
)

# Then get actual treatment compounds
actual_compounds, num_actual = get_compounds_with_treatments(graph)

# Analyze overlap
print(f"\nTotal number of compounds with actual treatment data: {num_actual}")
analysis = analyze_predictions_vs_treatments(predictions, actual_compounds)
# Out:
# Total number of compounds with actual treatment data: 451
#
# Disease::SARS-CoV2 E:
# Number of predicted compounds in treatment database: 0/20
# Percentage: 0.00%
# Overlapping compounds:
#
# Disease::SARS-CoV2 M:
# Number of predicted compounds in treatment database: 0/20
# Percentage: 0.00%
# Overlapping compounds:
#
# Disease::SARS-CoV2 N:
# Number of predicted compounds in treatment database: 0/20
# Percentage: 0.00%
# Overlapping compounds:
#
# Disease::SARS-CoV2 Spike:
# Number of predicted compounds in treatment database: 0/20
# Percentage: 0.00%
# Overlapping compounds:
#
# Disease::SARS-CoV2 nsp1:
# Number of predicted compounds in treatment database: 1/20
# Percentage: 5.00%
# Overlapping compounds:
# - Compound::DB14810
#
# Disease::SARS-CoV2 nsp10:
# Number of predicted compounds in treatment database: 0/20
# Percentage: 0.00%
# Overlapping compounds:
#
# Disease::SARS-CoV2 nsp11:
# Number of predicted compounds in treatment database: 0/20
# Percentage: 0.00%
# Overlapping compounds:
#
# Disease::SARS-CoV2 nsp12:
# Number of predicted compounds in treatment database: 0/20
# Percentage: 0.00%
# Overlapping compounds:
#
# Disease::SARS-CoV2 nsp13:
# Number of predicted compounds in treatment database: 0/20
# Percentage: 0.00%
# Overlapping compounds:
#
# Disease::SARS-CoV2 nsp14:
# Number of predicted compounds in treatment database: 0/20
# Percentage: 0.00%
# Overlapping compounds:
#
# Disease::SARS-CoV2 nsp15:
# Number of predicted compounds in treatment database: 0/20
# Percentage: 0.00%
# Overlapping compounds:
#
# Disease::SARS-CoV2 nsp2:
# Number of predicted compounds in treatment database: 0/20
# Percentage: 0.00%
# Overlapping compounds:
#
# Disease::SARS-CoV2 nsp4:
# Number of predicted compounds in treatment database: 0/20
# Percentage: 0.00%
# Overlapping compounds:
#
# Disease::SARS-CoV2 nsp5:
# Number of predicted compounds in treatment database: 1/20
# Percentage: 5.00%
# Overlapping compounds:
# - Compound::DB14999
#
# Disease::SARS-CoV2 nsp5_C145A:
# Number of predicted compounds in treatment database: 0/20
# Percentage: 0.00%
# Overlapping compounds:
#
# Disease::SARS-CoV2 nsp6:
# Number of predicted compounds in treatment database: 0/20
# Percentage: 0.00%
# Overlapping compounds:
#
# Disease::SARS-CoV2 nsp7:
# Number of predicted compounds in treatment database: 0/20
# Percentage: 0.00%
# Overlapping compounds:
#
# Disease::SARS-CoV2 nsp8:
# Number of predicted compounds in treatment database: 0/20
# Percentage: 0.00%
# Overlapping compounds:
#
# Disease::SARS-CoV2 nsp9:
# Number of predicted compounds in treatment database: 0/20
# Percentage: 0.00%
# Overlapping compounds:
#
# Disease::SARS-CoV2 orf10:
# Number of predicted compounds in treatment database: 0/20
# Percentage: 0.00%
# Overlapping compounds:
#
# Disease::SARS-CoV2 orf3a:
# Number of predicted compounds in treatment database: 0/20
# Percentage: 0.00%
# Overlapping compounds:
#
# Disease::SARS-CoV2 orf3b:
# Number of predicted compounds in treatment database: 0/20
# Percentage: 0.00%
# Overlapping compounds:
#
# Disease::SARS-CoV2 orf6:
# Number of predicted compounds in treatment database: 0/20
# Percentage: 0.00%
# Overlapping compounds:
#
# Disease::SARS-CoV2 orf7a:
# Number of predicted compounds in treatment database: 1/20
# Percentage: 5.00%
# Overlapping compounds:
# - Compound::DB00766
#
# Disease::SARS-CoV2 orf8:
# Number of predicted compounds in treatment database: 0/20
# Percentage: 0.00%
# Overlapping compounds:
#
# Disease::SARS-CoV2 orf9b:
# Number of predicted compounds in treatment database: 0/20
# Percentage: 0.00%
# Overlapping compounds:
#
# Disease::SARS-CoV2 orf9c:
# Number of predicted compounds in treatment database: 0/20
# Percentage: 0.00%
# Overlapping compounds:
#
# Disease::MESH:D045169:
# Number of predicted compounds in treatment database: 10/20
# Percentage: 50.00%
# Overlapping compounds:
# - Compound::DB00860
# - Compound::DB00563
# - Compound::DB01212
# - Compound::DB00165
# - Compound::DB01593
# - Compound::DB00741
# - Compound::DB00331
# - Compound::DB00982
# - Compound::DB09140
# - Compound::DB00811
#
# Disease::MESH:D045473:
# Number of predicted compounds in treatment database: 0/20
# Percentage: 0.00%
# Overlapping compounds:
#
# Disease::MESH:D001351:
# Number of predicted compounds in treatment database: 1/20
# Percentage: 5.00%
# Overlapping compounds:
# - Compound::DB04900
#
# Disease::MESH:D065207:
# Number of predicted compounds in treatment database: 0/20
# Percentage: 0.00%
# Overlapping compounds:
#
# Disease::MESH:D028941:
# Number of predicted compounds in treatment database: 0/20
# Percentage: 0.00%
# Overlapping compounds:
#
# Disease::MESH:D058957:
# Number of predicted compounds in treatment database: 0/20
# Percentage: 0.00%
# Overlapping compounds:
#
# Disease::MESH:D006517:
# Number of predicted compounds in treatment database: 0/20
# Percentage: 0.00%
# Overlapping compounds:

# %% [markdown]
# Note that final metrics were obtained using the metrics mentioned in the HGT notebook.
