# %%
# Install pykeen - package that is used to set up the pipeline
pip install pykeen
# Out:
# Requirement already satisfied: pykeen in /usr/local/lib/python3.10/dist-packages (1.11.0)
# Requirement already satisfied: dataclasses-json in /usr/local/lib/python3.10/dist-packages (from pykeen) (0.6.7)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pykeen) (1.26.4)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from pykeen) (1.13.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from pykeen) (8.1.7)
# Requirement already satisfied: click-default-group in /usr/local/lib/python3.10/dist-packages (from pykeen) (1.2.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from pykeen) (1.5.2)
# Requirement already satisfied: torch>=2.0 in /usr/local/lib/python3.10/dist-packages (from pykeen) (2.5.1+cu121)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from pykeen) (4.66.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from pykeen) (2.32.3)
# Requirement already satisfied: optuna>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from pykeen) (4.1.0)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from pykeen) (2.2.2)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from pykeen) (0.9.0)
# Requirement already satisfied: more-click in /usr/local/lib/python3.10/dist-packages (from pykeen) (0.1.2)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from pykeen) (10.5.0)
# Requirement already satisfied: pystow>=0.4.3 in /usr/local/lib/python3.10/dist-packages (from pykeen) (0.6.1)
# Requirement already satisfied: docdata in /usr/local/lib/python3.10/dist-packages (from pykeen) (0.0.4)
# Requirement already satisfied: class-resolver>=0.5.1 in /usr/local/lib/python3.10/dist-packages (from pykeen) (0.5.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from pykeen) (6.0.2)
# Requirement already satisfied: torch-max-mem>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from pykeen) (0.1.3)
# Requirement already satisfied: torch-ppr>=0.0.7 in /usr/local/lib/python3.10/dist-packages (from pykeen) (0.0.8)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from pykeen) (4.12.2)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from optuna>=2.0.0->pykeen) (1.14.0)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.10/dist-packages (from optuna>=2.0.0->pykeen) (6.9.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna>=2.0.0->pykeen) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.10/dist-packages (from optuna>=2.0.0->pykeen) (2.0.36)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->pykeen) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->pykeen) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->pykeen) (2024.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=2.0->pykeen) (3.16.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=2.0->pykeen) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0->pykeen) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=2.0->pykeen) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0->pykeen) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=2.0->pykeen) (1.3.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json->pykeen) (3.23.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json->pykeen) (0.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->pykeen) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->pykeen) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->pykeen) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->pykeen) (2024.8.30)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->pykeen) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->pykeen) (3.5.0)
# Requirement already satisfied: Mako in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna>=2.0.0->pykeen) (1.3.8)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.0->pykeen) (1.16.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.4.2->optuna>=2.0.0->pykeen) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->pykeen) (1.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=2.0->pykeen) (3.0.2)

# %%
# Mount Google Drive to work on relevant files
from google.colab import drive
drive.mount('/content/drive')

# Import necessary packages
import torch
from typing import Optional, Dict
from pykeen.models import RGCN
from pykeen.nn.modules import Interaction
from pykeen.triples import TriplesFactory
import numpy as np

class WeightedRGCN(RGCN):
    def __init__(
        self,
        triples_factory: TriplesFactory,
        embedding_dim: int = 64,
        num_layers: int = 2,
        edge_attributes: Optional[Dict[tuple, Dict[str, float]]] = None,
        dropout: float = 0.3,
        **kwargs
    ):
        super().__init__(
            triples_factory=triples_factory,
            embedding_dim=embedding_dim,
            num_layers=num_layers,
            **kwargs
        )

        # store edge attributes or initialize empty if None
        self.edge_attributes = edge_attributes or {}

        # define the attributes that will be processed for each edge
        self.string_attributes = [
            'coexpression',
            'experimentally_determined_interaction',
            'automated_textmining',
            'combined_score',
            'rmsd_score'
        ]

        # create NNs for processing each attribute type
        # each network converts a single attribute value into a weight
        self.attr_processors = torch.nn.ModuleDict({
            attr: torch.nn.Sequential(
                torch.nn.Linear(1, 8),
                torch.nn.ReLU(),
                torch.nn.Dropout(dropout),
                torch.nn.Linear(8, 1),
                torch.nn.Sigmoid()
            ) for attr in self.string_attributes
        })

        # attention combines all processed attributes into a single weight
        self.attr_attention = torch.nn.Sequential(
            torch.nn.Linear(len(self.string_attributes), 1),
            torch.nn.Sigmoid()
        )

        self.gradient_checkpointing = True

    def _get_edge_weights(self, h_idx, r_idx, t_idx):
        """
        Compute edge weights in a memory-efficient manner by processing data in chunks.
        """
        batch_size = len(h_idx)
        device = self.device

        # process data in chunks to reduce memory usage
        chunk_size = 1000
        all_weights = []

        # process each chunk
        for i in range(0, batch_size, chunk_size):
            chunk_h = h_idx[i:i + chunk_size]
            chunk_r = r_idx[i:i + chunk_size]
            chunk_t = t_idx[i:i + chunk_size]

            # initialize attribute values with default of 0.5
            chunk_attr_values = torch.ones(len(chunk_h), len(self.string_attributes), device=device) * 0.5

            # process each triple in the chunk
            for j, (h, r, t) in enumerate(zip(chunk_h, chunk_r, chunk_t)):
                # Get attributes for current edge
                edge_attrs = self.edge_attributes.get((h.item(), r.item(), t.item()), {})

                # process each attribute
                for k, attr in enumerate(self.string_attributes):
                    value = edge_attrs.get(attr, 0.5)  # Default to 0.5 if attribute missing
                    if isinstance(value, str) and value == 'N/A':
                        value = 0.5  # Handle N/A values
                    chunk_attr_values[j, k] = float(value)

            # process each attribute through its NN
            processed_attrs = []
            for attr_idx, attr in enumerate(self.string_attributes):
                attr_val = chunk_attr_values[:, attr_idx:attr_idx+1]
                processed_val = self.attr_processors[attr](attr_val)
                processed_attrs.append(processed_val)

            # combine processed attributes using attention mechanism
            chunk_combined = torch.cat(processed_attrs, dim=1)
            chunk_weights = self.attr_attention(chunk_combined)
            all_weights.append(chunk_weights)

        # combine all chunk weights and remove extra dimensions
        return torch.cat(all_weights, dim=0).squeeze(-1)

    def forward(
        self,
        h_indices: torch.LongTensor,
        r_indices: torch.LongTensor,
        t_indices: torch.LongTensor,
        mode: Optional[str] = None,
    ) -> torch.FloatTensor:
        """
        Forward pass of the model, combining RGCN scores with computed edge weights.
        """
        if mode is None:

            # training mode: compute full weights
            if self.gradient_checkpointing and self.training:

                # use gradient checkpointing to save memory during training
                weights = torch.utils.checkpoint.checkpoint(
                    self._get_edge_weights,
                    h_indices, r_indices, t_indices
                )
            else:
                weights = self._get_edge_weights(h_indices, r_indices, t_indices)

            # get base RGCN scores and multiply by computed weights
            scores = super().forward(h_indices, r_indices, t_indices)
            return scores * weights
        else:
            # prediction mode: use default weight of 0.5
            scores = super().forward(h_indices, r_indices, t_indices, mode=mode)

# %%
def graph_to_edge_attributes(graph) -> Dict[tuple, Dict[str, float]]:
    """convert NetworkX graph edge attributes to dictionary format."""
    edge_attrs = {}
    for u, v, data in graph.edges(data=True):

        # get relation type
        relation = data.get('relation', 'related_to')

        # extract STRING attributes
        attrs = {
            'coexpression': data.get('coexpression', 'N/A'),
            'experimentally_determined_interaction': data.get('experimentally_determined_interaction', 'N/A'),
            'automated_textmining': data.get('automated_textmining', 'N/A'),
            'combined_score': data.get('combined_score', 'N/A'),
            'rmsd_score': data.get('rmsd_score', 'N/A')
        }

        # store attributes keyed by (head, relation, tail)
        edge_attrs[(u, relation, v)] = attrs

    return edge_attrs

# %%
# Import necessary packages
import pickle
from pykeen.pipeline import pipeline
import torch
import logging
from sklearn.model_selection import train_test_split

def prepare_data(graph_path: str):
    """
    Prepare graph data for training by creating train/test/validation splits of triplets
    """
    # Load the graph
    with open(graph_path, "rb") as f:
        graph = pickle.load(f)

    # Extract triples and edge attributes
    triples = []
    for source, target, data in graph.edges(data=True):
        relation = data.get('relation', 'related_to')
        triples.append((str(source), str(relation), str(target)))

    # Convert to numpy array for splitting
    triples_array = np.array(triples)

    # Create train/test split first
    train_val_triples, test_triples = train_test_split(
        triples_array,
        test_size=0.1,
        random_state=42
    )

    # Create train/validation split
    train_triples, val_triples = train_test_split(
        train_val_triples,
        test_size=0.11111,
        random_state=42
    )

    # Create factories
    training_factory = TriplesFactory.from_labeled_triples(train_triples)
    validation_factory = TriplesFactory.from_labeled_triples(val_triples)
    testing_factory = TriplesFactory.from_labeled_triples(test_triples)

    # Get edge attributes
    edge_attributes = graph_to_edge_attributes(graph)

    return training_factory, testing_factory, validation_factory, edge_attributes

# %%
# Path to graph
graph_path = "/content/drive/MyDrive/Colabs/data/graph_w_covid_genes_treatments_string_cif_coalesced_3.pkl"

# Prepare data
train_factory, test_factory, val_factory, edge_attrs = prepare_data(graph_path)

# %%
# Import necessary packages for pipeline
from pykeen.pipeline import pipeline
from pykeen.triples import TriplesFactory
from typing import Dict, List, Tuple
import torch
from pykeen.predict import predict_target

def train_weighted_rgcn(
    training_factory: TriplesFactory,
    testing_factory: TriplesFactory,
    validation_factory: TriplesFactory,
    edge_attributes: Dict,
) -> Dict:
    """
    Create a RGCN pipeline to train the model
    """
    return pipeline(
        model=MemoryEfficientWeightedRGCN,
        model_kwargs={
            'edge_attributes': edge_attributes,
            'embedding_dim': 100,  # Dimension of embeddings
            'num_layers': 2,       # Number of RGCN layers
        },
      training_kwargs={
          'num_epochs': 50,
          'batch_size': 6000,
      },
        training=training_factory,
        testing=testing_factory,
        validation=validation_factory,
        training_loop='slcwa',
        optimizer='adam',
        device='cuda'
    )

# Train on CPU with sampled data
result = train_weighted_rgcn(
    training_factory=train_factory,
    testing_factory=test_factory,
    validation_factory=val_factory,
    edge_attributes=edge_attrs
)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Extracted 5050817 triples from the graph.
# INFO:pykeen.pipeline.api:Using device: cuda
# INFO:pykeen.nn.message_passing:No num_bases was provided. Using sqrt(num_relations)=10.
# INFO:pykeen.nn.message_passing:No num_bases was provided. Using sqrt(num_relations)=10.
# INFO:pykeen.nn.message_passing:No num_bases was provided. Using sqrt(num_relations)=10.
# INFO:pykeen.nn.message_passing:No num_bases was provided. Using sqrt(num_relations)=10.
# WARNING:pykeen.nn.message_passing:Layers RGCNLayer(
#   (fwd): BasesDecomposition(
#     (relation_representations): LowRankRepresentation(
#       (bases): Embedding(
#         (_embeddings): Embedding(10, 10000)
#       )
#     )
#   )
#   (bwd): BasesDecomposition(
#     (relation_representations): LowRankRepresentation(
#       (bases): Embedding(
#         (_embeddings): Embedding(10, 10000)
#       )
#     )
#   )
#   (self_loop): Linear(in_features=100, out_features=100, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
# ) has parameters, but no reset_parameters.
# WARNING:pykeen.nn.message_passing:Layers RGCNLayer(
#   (fwd): BasesDecomposition(
#     (relation_representations): LowRankRepresentation(
#       (bases): Embedding(
#         (_embeddings): Embedding(10, 10000)
#       )
#     )
#   )
#   (bwd): BasesDecomposition(
#     (relation_representations): LowRankRepresentation(
#       (bases): Embedding(
#         (_embeddings): Embedding(10, 10000)
#       )
#     )
#   )
#   (self_loop): Linear(in_features=100, out_features=100, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
# ) has parameters, but no reset_parameters.
# WARNING:pykeen.training.training_loop:Using RGCN without graph-based sampling! Please select sampler="schlichtkrull" instead of None.
# WARNING:pykeen.training.training_loop:Using RGCN without graph-based sampling! Please select sampler="schlichtkrull" instead of None.
# WARNING:pykeen.nn.message_passing:Layers RGCNLayer(
#   (fwd): BasesDecomposition(
#     (relation_representations): LowRankRepresentation(
#       (bases): Embedding(
#         (_embeddings): Embedding(10, 10000)
#       )
#     )
#   )
#   (bwd): BasesDecomposition(
#     (relation_representations): LowRankRepresentation(
#       (bases): Embedding(
#         (_embeddings): Embedding(10, 10000)
#       )
#     )
#   )
#   (self_loop): Linear(in_features=100, out_features=100, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
# ) has parameters, but no reset_parameters.
# WARNING:pykeen.nn.message_passing:Layers RGCNLayer(
#   (fwd): BasesDecomposition(
#     (relation_representations): LowRankRepresentation(
#       (bases): Embedding(
#         (_embeddings): Embedding(10, 10000)
#       )
#     )
#   )
#   (bwd): BasesDecomposition(
#     (relation_representations): LowRankRepresentation(
#       (bases): Embedding(
#         (_embeddings): Embedding(10, 10000)
#       )
#     )
#   )
#   (self_loop): Linear(in_features=100, out_features=100, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
# ) has parameters, but no reset_parameters.
# WARNING:pykeen.nn.message_passing:Layers RGCNLayer(
#   (fwd): BasesDecomposition(
#     (relation_representations): LowRankRepresentation(
#       (bases): Embedding(
#         (_embeddings): Embedding(10, 10000)
#       )
#     )
#   )
#   (bwd): BasesDecomposition(
#     (relation_representations): LowRankRepresentation(
#       (bases): Embedding(
#         (_embeddings): Embedding(10, 10000)
#       )
#     )
#   )
#   (self_loop): Linear(in_features=100, out_features=100, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
# ) has parameters, but no reset_parameters.
# WARNING:pykeen.nn.message_passing:Layers RGCNLayer(
#   (fwd): BasesDecomposition(
#     (relation_representations): LowRankRepresentation(
#       (bases): Embedding(
#         (_embeddings): Embedding(10, 10000)
#       )
#     )
#   )
#   (bwd): BasesDecomposition(
#     (relation_representations): LowRankRepresentation(
#       (bases): Embedding(
#         (_embeddings): Embedding(10, 10000)
#       )
#     )
#   )
#   (self_loop): Linear(in_features=100, out_features=100, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
# ) has parameters, but no reset_parameters.
# Training epochs on cuda:0:   0%|          | 0/50 [00:00<?, ?epoch/s]
# Training batches on cuda:0:   0%|          | 0/674 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/674 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/674 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/674 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/674 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/674 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/674 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/674 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/674 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/674 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/674 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/674 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/674 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/674 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/674 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/674 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/674 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/674 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/674 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/674 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/674 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/674 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/674 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/674 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/674 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/674 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/674 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/674 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/674 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/674 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/674 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/674 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/674 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/674 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/674 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/674 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/674 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/674 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/674 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/674 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/674 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/674 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/674 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/674 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/674 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/674 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/674 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/674 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/674 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/674 [00:00<?, ?batch/s]
# Evaluating on cuda:0:   0%|          | 0.00/505k [00:00<?, ?triple/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 345.75s seconds

# %%
# Import necessary modules
import os
import pickle

# Retrieve the trained model from the pipeline result
model = result

# Define the path where the model will be saved
save_path = '/content/drive/MyDrive/my_models/trained_rgcn_new_graph_model_pipeline_result_weights.pkl'
directory = os.path.dirname(save_path)

# Check if the directory exists, and if not, create it
if not os.path.exists(directory):
    os.makedirs(directory)

# Save the model to the specified path using pickle
with open(save_path, 'wb') as f:
    pickle.dump(model, f)

# %%
# Get evaluation results
results = result.metric_results.to_dict()
print("\nModel Evaluation Results:")
print(results)

# Get embeddings correctly
entity_embeddings = pipeline_result.model.entity_representations[0](indices=None).cpu().detach().numpy()
relation_embeddings = pipeline_result.model.relation_representations[0](indices=None).cpu().detach().numpy()
# Out:
# Model Evaluation Results:
# {'head': {'optimistic': {'adjusted_geometric_mean_rank_index': -1.205822912937747, 'z_arithmetic_mean_rank': -851.0719297755124, 'median_absolute_deviation': 7797.746368230213, 'z_geometric_mean_rank': -858.9264914320823, 'inverse_geometric_mean_rank': 1.2793998710895143e-05, 'adjusted_inverse_harmonic_mean_rank': -0.00010848016987911259, 'variance': 286763808.1124392, 'inverse_median_rank': 1.133780420745914e-05, 'inverse_arithmetic_mean_rank': 1.227691131859031e-05, 'adjusted_arithmetic_mean_rank_index': -0.6913997360030824, 'geometric_mean_rank': 78161.64614339203, 'harmonic_mean_rank': 59985.28350980916, 'z_inverse_harmonic_mean_rank': -18.66165517941274, 'inverse_harmonic_mean_rank': 1.667075558351698e-05, 'adjusted_arithmetic_mean_rank': 1.6913853790956501, 'count': 505082.0, 'standard_deviation': 16934.101928134223, 'arithmetic_mean_rank': 81453.71209823355, 'median_rank': 88200.5, 'hits_at_1': 0.0, 'hits_at_3': 0.0, 'hits_at_5': 0.0, 'hits_at_10': 3.959753069798567e-06, 'z_hits_at_k': -6.965771293865634, 'adjusted_hits_at_k': -9.987663938510777e-05}, 'realistic': {'adjusted_geometric_mean_rank_index': -1.2058196704558946, 'z_arithmetic_mean_rank': -851.072099801286, 'median_absolute_deviation': 7797.746368230213, 'z_geometric_mean_rank': -858.9241817616231, 'inverse_geometric_mean_rank': 1.2794017493433785e-05, 'adjusted_inverse_harmonic_mean_rank': -0.00010848016770322765, 'variance': 286763776.0, 'inverse_median_rank': 1.1337804608047009e-05, 'inverse_arithmetic_mean_rank': 1.227691063832026e-05, 'adjusted_arithmetic_mean_rank_index': -0.6913998741298031, 'geometric_mean_rank': 78161.53125, 'harmonic_mean_rank': 59985.275681446255, 'z_inverse_harmonic_mean_rank': -18.661654805099033, 'inverse_harmonic_mean_rank': 1.667075775912963e-05, 'adjusted_arithmetic_mean_rank': 1.6913855172195027, 'count': 505082.0, 'standard_deviation': 16934.1015625, 'arithmetic_mean_rank': 81453.71875, 'median_rank': 88200.5, 'hits_at_1': 0.0, 'hits_at_3': 0.0, 'hits_at_5': 0.0, 'hits_at_10': 3.959753069798567e-06, 'z_hits_at_k': -6.965771293865634, 'adjusted_hits_at_k': -9.987663938510777e-05}, 'pessimistic': {'adjusted_geometric_mean_rank_index': -1.2058229919906756, 'z_arithmetic_mean_rank': -851.0719921747025, 'median_absolute_deviation': 7797.746368230213, 'z_geometric_mean_rank': -858.9265477427178, 'inverse_geometric_mean_rank': 1.2793998252385948e-05, 'adjusted_inverse_harmonic_mean_rank': -0.00010848017053587477, 'variance': 286763774.4454623, 'inverse_median_rank': 1.133780420745914e-05, 'inverse_arithmetic_mean_rank': 1.2276910950648274e-05, 'adjusted_arithmetic_mean_rank_index': -0.6913997866953703, 'geometric_mean_rank': 78161.6489445362, 'harmonic_mean_rank': 59985.28587269772, 'z_inverse_harmonic_mean_rank': -18.661655292394396, 'inverse_harmonic_mean_rank': 1.6670754926836977e-05, 'adjusted_arithmetic_mean_rank': 1.6913854297868856, 'count': 505082.0, 'standard_deviation': 16934.100934075665, 'arithmetic_mean_rank': 81453.71453942131, 'median_rank': 88200.5, 'hits_at_1': 0.0, 'hits_at_3': 0.0, 'hits_at_5': 0.0, 'hits_at_10': 3.959753069798567e-06, 'z_hits_at_k': -6.965771293865634, 'adjusted_hits_at_k': -9.987663938510777e-05}}, 'tail': {'optimistic': {'adjusted_geometric_mean_rank_index': -0.23003272642595962, 'z_arithmetic_mean_rank': -208.68339957098533, 'median_absolute_deviation': 37563.20980805793, 'z_geometric_mean_rank': -163.60471290349756, 'inverse_geometric_mean_rank': 2.4877618166642836e-05, 'adjusted_inverse_harmonic_mean_rank': -7.14040448796814e-05, 'variance': 770832497.3732773, 'inverse_median_rank': 1.8294914013904136e-05, 'inverse_arithmetic_mean_rank': 1.9227868360711588e-05, 'adjusted_arithmetic_mean_rank_index': -0.1697181101135452, 'geometric_mean_rank': 40196.77419685018, 'harmonic_mean_rank': 15746.807143884736, 'z_inverse_harmonic_mean_rank': -11.790132574476244, 'inverse_harmonic_mean_rank': 6.350493727792618e-05, 'adjusted_arithmetic_mean_rank': 1.1697142929644466, 'count': 505082.0, 'standard_dev ...

# %%
# Define the list of COVID-related diseases
COV_disease_list = [
    "Disease::SARS-CoV2 E",
    "Disease::SARS-CoV2 M",
    "Disease::SARS-CoV2 N",
    "Disease::SARS-CoV2 Spike",
    "Disease::SARS-CoV2 nsp1",
    "Disease::SARS-CoV2 nsp10",
    "Disease::SARS-CoV2 nsp11",
    "Disease::SARS-CoV2 nsp12",
    "Disease::SARS-CoV2 nsp13",
    "Disease::SARS-CoV2 nsp14",
    "Disease::SARS-CoV2 nsp15",
    "Disease::SARS-CoV2 nsp2",
    "Disease::SARS-CoV2 nsp4",
    "Disease::SARS-CoV2 nsp5",
    "Disease::SARS-CoV2 nsp5_C145A",
    "Disease::SARS-CoV2 nsp6",
    "Disease::SARS-CoV2 nsp7",
    "Disease::SARS-CoV2 nsp8",
    "Disease::SARS-CoV2 nsp9",
    "Disease::SARS-CoV2 orf10",
    "Disease::SARS-CoV2 orf3a",
    "Disease::SARS-CoV2 orf3b",
    "Disease::SARS-CoV2 orf6",
    "Disease::SARS-CoV2 orf7a",
    "Disease::SARS-CoV2 orf8",
    "Disease::SARS-CoV2 orf9b",
    "Disease::SARS-CoV2 orf9c",
    "Disease::MESH:D045169",
    "Disease::MESH:D045473",
    "Disease::MESH:D001351",
    "Disease::MESH:D065207",
    "Disease::MESH:D028941",
    "Disease::MESH:D058957",
    "Disease::MESH:D006517",
]

# %%
def get_top_predictions(
    model,
    training_factory,
    relation: str,
    tail_entities: List[str],
    k: int = 20
) -> dict:
    """
    Get top 20 compund predictions for given tail (COVID) entities and relation.
    """
    results = {}

    for tail in tail_entities:
        try:
            # Use predict_target to get predictions
            predictions = predict_target(
                model=model,
                tail=tail,
                relation=relation,
                triples_factory=training_factory
            )

            # Get the results as a dataframe and apply the filter
            df = predictions.df

            # Filter for only Compound predictions
            compound_df = df[df['head_label'].str.startswith('Compound::')].sort_values('score', ascending=False)

            if compound_df.empty:
                print(f"Warning: No compound predictions found for {tail}")
                continue

            # Get top k predictions
            top_k_df = compound_df.head(k)

            # Convert to list of (compound, score) tuples
            head_scores = list(zip(top_k_df['head_label'], top_k_df['score']))
            results[tail] = head_scores

        except KeyError as e:
            print(f"Warning: Entity or relation not found in training data: {e}")
            continue

        except Exception as e:
            print(f"Error predicting for {tail}: {str(e)}")
            continue

    return results

# Get predictions for COVID diseases
relation = "DRKG::Treats::Compound:Disease"
predictions = get_top_predictions(
    pipeline_result.model,
    training_factory,
    relation,
    COV_disease_list
)

# Print results
print("\nTop 20 predicted compounds for each disease:")
for disease, compounds in predictions.items():
    if compounds:  # Only print if we have compound predictions
        print(f"\n{disease}:")
        for i, (compound, score) in enumerate(compounds, 1):
            print(f"{i}. {compound} (score: {score:.4f})")
# Out:
# Top 20 predicted compounds for each disease:
#
# Disease::SARS-CoV2 E:
# 1. Compound::CHEMBL432600 (score: 0.6069)
# 2. Compound::CHEMBL2109193 (score: 0.5830)
# 3. Compound::DB07384 (score: 0.5689)
# 4. Compound::brenda:104600 (score: 0.5578)
# 5. Compound::pubchem:407294 (score: 0.5544)
# 6. Compound::MESH:C403563 (score: 0.5312)
# 7. Compound::DB05033 (score: 0.5189)
# 8. Compound::brenda:226203 (score: 0.5130)
# 9. Compound::DB06098 (score: 0.4925)
# 10. Compound::DB08629 (score: 0.4732)
# 11. Compound::zinc:ZINC000005650745 (score: 0.4598)
# 12. Compound::DB06734 (score: 0.4454)
# 13. Compound::CHEMBL2109474 (score: 0.4336)
# 14. Compound::DB01790 (score: 0.4263)
# 15. Compound::DB03478 (score: 0.4078)
# 16. Compound::DB06103 (score: 0.3818)
# 17. Compound::DB07546 (score: 0.3799)
# 18. Compound::brenda:222144 (score: 0.3651)
# 19. Compound::CHEMBL460785 (score: 0.3649)
# 20. Compound::DB12109 (score: 0.3613)
#
# Disease::SARS-CoV2 M:
# 1. Compound::DB06098 (score: 1.3097)
# 2. Compound::CHEMBL3137353 (score: 0.8452)
# 3. Compound::brenda:7480 (score: 0.7770)
# 4. Compound::brenda:36309 (score: 0.7708)
# 5. Compound::molport:MolPort-003-940-835 (score: 0.7057)
# 6. Compound::brenda:226203 (score: 0.6875)
# 7. Compound::brenda:12270 (score: 0.6623)
# 8. Compound::CHEMBL2108628 (score: 0.6609)
# 9. Compound::CHEMBL2109193 (score: 0.6555)
# 10. Compound::brenda:222144 (score: 0.6360)
# 11. Compound::DB01902 (score: 0.6116)
# 12. Compound::CHEMBL27885 (score: 0.6007)
# 13. Compound::DB06784 (score: 0.5715)
# 14. Compound::DB12563 (score: 0.5603)
# 15. Compound::DB14523 (score: 0.5364)
# 16. Compound::rhea:28195 (score: 0.5338)
# 17. Compound::DB07115 (score: 0.5046)
# 18. Compound::DB08356 (score: 0.4691)
# 19. Compound::CHEMBL2107846 (score: 0.4138)
# 20. Compound::brenda:12356 (score: 0.4125)
#
# Disease::SARS-CoV2 N:
# 1. Compound::brenda:49917 (score: 1.2694)
# 2. Compound::brenda:226203 (score: 0.9809)
# 3. Compound::bindingdb:50088446 (score: 0.8935)
# 4. Compound::DB08916 (score: 0.8581)
# 5. Compound::DB08931 (score: 0.8458)
# 6. Compound::DB08878 (score: 0.7676)
# 7. Compound::DB00877 (score: 0.7396)
# 8. Compound::brenda:36309 (score: 0.7320)
# 9. Compound::DB07384 (score: 0.7318)
# 10. Compound::DB07045 (score: 0.7275)
# 11. Compound::MESH:C541938 (score: 0.7016)
# 12. Compound::DB05668 (score: 0.6995)
# 13. Compound::CHEMBL2108628 (score: 0.6987)
# 14. Compound::CHEMBL2109193 (score: 0.6972)
# 15. Compound::DB06098 (score: 0.6733)
# 16. Compound::brenda:219695 (score: 0.6724)
# 17. Compound::DB04855 (score: 0.6715)
# 18. Compound::zinc:ZINC000005650745 (score: 0.6570)
# 19. Compound::brenda:71529 (score: 0.6532)
# 20. Compound::brenda:21348 (score: 0.6503)
#
# Disease::SARS-CoV2 Spike:
# 1. Compound::DB00602 (score: 1.0585)
# 2. Compound::DB00877 (score: 1.0509)
# 3. Compound::DB00091 (score: 1.0174)
# 4. Compound::DB00563 (score: 0.9963)
# 5. Compound::CHEMBL1200382 (score: 0.8762)
# 6. Compound::DB03408 (score: 0.8464)
# 7. Compound::DB01165 (score: 0.7567)
# 8. Compound::DB14513 (score: 0.7487)
# 9. Compound::DB00468 (score: 0.6691)
# 10. Compound::DB11562 (score: 0.6607)
# 11. Compound::bindingdb:50067593 (score: 0.6403)
# 12. Compound::DB09116 (score: 0.6241)
# 13. Compound::DB00250 (score: 0.6058)
# 14. Compound::CHEMBL2109224 (score: 0.5807)
# 15. Compound::bindingdb:50088446 (score: 0.5793)
# 16. Compound::MESH:D010406 (score: 0.5724)
# 17. Compound::CHEMBL3544952 (score: 0.5686)
# 18. Compound::DB00916 (score: 0.5580)
# 19. Compound::DB01098 (score: 0.5432)
# 20. Compound::MESH:D016559 (score: 0.5421)
#
# Disease::SARS-CoV2 nsp1:
# 1. Compound::DB06098 (score: 0.6208)
# 2. Compound::DB07384 (score: 0.4837)
# 3. Compound::DB09116 (score: 0.4819)
# 4. Compound::MESH:C495818 (score: 0.4582)
# 5. Compound::CHEMBL3137353 (score: 0.4539)
# 6. Compound::MESH:C579148 (score: 0.4194)
# 7. Compound::MESH:C403563 (score: 0.3794)
# 8. Compound::brenda:226203 (score: 0.3493)
# 9. Compound::MESH:D060172 (score: 0.3171)
# 10. Compound::DB03478 (score: 0.2970)
# 11. Compound::DB07546 (score: 0.2869)
# 12. Compound::MESH:C542662 (score: 0.2817)
# 13. Compound::DB06103 (score: 0.2604)
# 14. Compound::DB04436 (score: 0.2438)
# 15. Compound::DB08464 (score: 0.2433)
# 16. Compound::MESH:C000592914 (score: 0.2429)
# 17. Compound::DB08191 (score: 0.2428)
# 18. Compound::MESH:C516714 (score: 0.2397)
# 19. Compound::DB05033 (score: 0.2376)
# 20. Compound::DB07350 (score: 0.2357)
#
# Disease::SARS-CoV2 nsp10:
# 1. Compound::CHEBI:18186 (score: 3.2812)
# 2. Compound::MESH:D014443 (score: 2.9017)
# 3. Compound::DB01229 (score: 2.5571)
# 4. Compound::DB00877 (score: 2.5400)
# 5. Compound::DB04216 (score: 2.4017)
# 6. Compound::DB12010 (score: 2.1316)
# 7. Compound::DB09079 (score: 2.0173)
# 8. Compound::CHEBI:61292 (score: 1.9967)
# 9. Compound::DB00091 (score: 1.9967)
# 10. Compound::DB00171 (score: 1.9217)
# 11. Compound::DB00641 (score: 1.8879)
# 12. Compound::DB02010 (score: 1.8753)
# 13. Compound::DB00759 (score: 1.8043)
# 14. Compound::DB00441 (score: 1.6780)
# 15. Compound::DB04315 (score: 1.6544)
# 16. Compound::DB00563 (score: 1.6510)
# 17. Compound::DB11091 (score: 1.6279)
# 18. Compound::DB11805 (score: 1.5805)
# 19. Compound::DB01254 (score: 1.5417)
# 20. Compound::DB00997 (score: 1.4965)
#
# Disease::SARS-CoV2 nsp11:
# 1. Compound::CHEBI:18186 (score: 0.7918)
# 2. Compound::DB00877 (score: 0.5340)
# 3. Compound::DB08235 (score: 0.4155)
# 4. Compound::DB06098 (score: 0.3570)
# 5. Compound::DB08236 (score: 0.2816)
# 6. Compound::MESH:C581155 (score: 0.2451)
# 7. Compound::DB05033 (score: 0.2340)
# 8. Compound::MESH:C025160 (score: 0.2268)
# 9. Compound::DB07384 (score: 0.2250)
# 10. Compound::DB04699 (score: 0.2246)
# 11. Compound::MESH:C579147 (score: 0.1979)
# 12. Compound::MESH:C410027 (score: 0.1827)
# 13. Compound::MESH:C403563 (score: 0.1811)
# 14. Compound::DB14017 (score: 0.1768)
# 15. Compound::DB01790 (score: 0.1604)
# 16. Compound::DB08191 (score: 0.1585)
# 17. Compound::DB12484 (score: 0.1239)
# 18. Compound::DB04531 (score: 0.1180)
# 19. Compound::DB08629 (score: 0.1053)
# 20. Compound::brenda:226203 (score: 0.1044)
#
# Disease::SARS-CoV2 nsp12:
# 1. Compound::brenda:49917 (score: 1.0886)
# 2. Compound::DB14481 (score: 0.9743)
# 3. Compound::bindingdb:50088446 (score: 0.9659)
# 4. Compound::bindingdb:50028010 (score: 0.9600)
# 5. Compound::brenda:226203 (score: 0.9577)
# 6. Compound::DB14523 (score: 0.8949)
# 7. Compound::DB08687 (score: 0.8254)
# 8. Compound::DB08378 (score: 0.8032)
# 9. Compound::DB02423 (score: 0.7551)
# 10. Compound::CHEMBL3833346 (score: 0.7471)
# 11. Compound::DB01902 (score: 0.7402)
# 12. Compound::DB12451 (score: 0.7026)
# 13. Compound::rhea:28195 (score: 0.6694)
# 14. Compound::hmdb:HMDB0014609 (score: 0.6616)
# 15. Compound::brenda:71529 (score: 0.6600)
# 16. Compound::brenda:219695 (score: 0.6569)
# 17. Compound::DB08848 (score: 0.6558)
# 18. Compound::DB07045 (score: 0.6334)
# 19. Compound::rhea:44348 (score: 0.6325)
# 20. Compound::DB12426 (score: 0.6182)
#
# Disease::SARS-CoV2 nsp13:
# 1. Compound::CHEBI:61292 (score: 3.8133)
# 2. Compound::DB00877 (score: 3.4222)
# 3. Compound::CHEBI:18186 (score: 3.3998)
# 4. Compound::DB05294 (score: 3.2827)
# 5. Compound::DB02527 (score: 3.2041)
# 6. Compound::DB12010 (score: 2.8511)
# 7. Compound::DB08865 (score: 2.8162)
# 8. Compound::DB02010 (score: 2.7856)
# 9. Compound::brenda:21348 (score: 2.7724)
# 10. Compound::DB04855 (score: 2.7401)
# 11. Compound::MESH:D014443 (score: 2.6217)
# 12. Compound::MESH:D008094 (score: 2.5065)
# 13. Compound::DB00171 (score: 2.4557)
# 14. Compound::brenda:71529 (score: 2.1039)
# 15. Compound::bindingdb:50028010 (score: 2.0826)
# 16. Compound::DB12774 (score: 2.0656)
# 17. Compound::DB01118 (score: 2.0488)
# 18. Compound::DB06836 (score: 2.0006)
# 19. Compound::DB01115 (score: 1.9795)
# 20. Compound::DB02656 (score: 1.9489)
#
# Disease::SARS-CoV2 nsp14:
# 1. Compound::DB09116 (score: 0.9103)
# 2. Compound::DB06098 (score: 0.7073)
# 3. Compound::DB05033 (score: 0.6172)
# 4. Compound::MESH:D000214 (score: 0.6021)
# 5. Compound::brenda:222144 (score: 0.5612)
# 6. Compound::pubchem:407294 (score: 0.5075)
# 7. Compound::molport:MolPort-046-588-736 (score: 0.4556)
# 8. Compound::brenda:104600 (score: 0.4387)
# 9. Compound::DB04531 (score: 0.4008)
# 10. Compound::DB07384 (score: 0.3723)
# 11. Compound::DB01098 (score: 0.3704)
# 12. Compound::DB08878 (score: 0.3671)
# 13. Compound::DB05483 (score: 0.3657)
# 14. Compound::DB06103 (score: 0.3453)
# 15. Compound::DB08235 (score: 0.3374)
# 16. Compound::DB12484 (score: 0.3225)
# 17. Compound::DB04207 (score: 0.3205)
# 18. Compound::zinc:ZINC000005650745 (score: 0.3193)
# 19. Compound::brenda:221264 (score: 0.3088)
# 20. Compound::MESH:D003571 (score: 0.3083)
#
# Disease::SARS-CoV2 nsp15:
# 1. Compound::DB00877 (score: 3.3471)
# 2. Compound::DB12010 (score: 3.3311)
# 3. Compound::CHEBI:18186 (score: 3.0729)
# 4. Compound::DB02010 (score: 2.5527)
# 5. Compound::DB04216 (score: 2.5320)
# 6. Compound::DB00171 (score: 2.4924)
# 7. Compound::MESH:D014443 (score: 2.3988)
# 8. Compound::CHEBI:61292 (score: 2.3086)
# 9. Compound::DB01229 (score: 2.2502)
# 10. Compound::DB09079 (score: 2.1358)
# 11. Compound::DB04137 (score: 2.1183)
# 12. Compound::DB04315 (score: 2.0244)
# 13. Compound::DB08931 (score: 2.0223)
# 14. Compound::DB00091 (score: 1.9288)
# 15. Compound::DB00641 (score: 1.8582)
# 16. Compound::DB01118 (score: 1.8530)
# 17. Compound::DB00201 (score: 1.7545)
# 18. Compound::DB02527 (score: 1.6503)
# 19. Compound::DB01115 (score: 1.6359)
# 20. Compound::DB12695 (score: 1.5717)
#
# Disease::SARS-CoV2 nsp2:
# 1. Compound::DB07384 (score: 0.5783)
# 2. Compound::DB06098 (score: 0.3910)
# 3. Compound::DB02624 (score: 0.3221)
# 4. Compound::DB08629 (score: 0.3195)
# 5. Compound::brenda:49917 (score: 0.2706)
# 6. Compound::DB04436 (score: 0.2237)
# 7. Compound::CHEMBL2108628 (score: 0.2189)
# 8. Compound::rhea:44348 (score: 0.2136)
# 9. Compound::CHEMBL2109193 (score: 0.2109)
# 10. Compound::DB02082 (score: 0.1845)
# 11. Compound::MESH:C403563 (score: 0.1801)
# 12. Compound::MESH:C522060 (score: 0.1705)
# 13. Compound::MESH:C410786 (score: 0.1511)
# 14. Compound::CHEBI:27845 (score: 0.1314)
# 15. Compound::brenda:7480 (score: 0.1033)
# 16. Compound::brenda:226203 (score: 0.1030)
# 17. Compound::MESH:C542662 (score: 0.0857)
# 18. Compound::pubchem:407294 (score: 0.0810)
# 19. Compound::DB05033 (score: 0.0741)
# 20. Compound::DB03478 (score: 0.0719)
#
# Disease::SARS-CoV2 nsp4:
# 1. Compound::DB06098 (score: 1.1238)
# 2. Compound::molport:MolPort-003-940-835 (score: 0.7118)
# 3. Compound::brenda:7480 (score: 0.7108)
# 4. Compound::brenda:222144 (score: 0.6419)
# 5. Compound::brenda:36309 (score: 0.5352)
# 6. Compound::brenda:104600 (score: 0.5127)
# 7. Compound::DB07384 (score: 0.4947)
# 8. Compound::DB07045 (score: 0.4830)
# 9. Compound::DB05033 (score: 0.4657)
# 10. Compound::brenda:226203 (score: 0.4536)
# 11. Compound::pubchem:407294 (score: 0.4472)
# 12. Compound::molport:MolPort-046-588-736 (score: 0.4366)
# 13. Compound::DB04531 (score: 0.4251)
# 14. Compound::brenda:49917 (score: 0.4247)
# 15. Compound::brenda:43171 (score: 0.4133)
# 16. Compound::DB06784 (score: 0.4131)
# 17. Compound::DB04803 (score: 0.3617)
# 18. Compound::brenda:174399 (score: 0.3533)
# 19. Compound::DB15496 (score: 0.3487)
# 20. Compound::DB07347 (score: 0.3457)
#
# Disease::SARS-CoV2 nsp5:
# 1. Compound::MESH:C579148 (score: 0.7074)
# 2. Compound::MESH:C403563 (score: 0.6625)
# 3. Compound::MESH:C025160 (score: 0.6572)
# 4. Compound::MESH:C581155 (score: 0.5702)
# 5. Compound::MESH:C505456 (score: 0.5597)
# 6. Compound::DB08655 (score: 0.5371)
# 7. Compound::MESH:C482098 (score: 0.5160)
# 8. Compound::DB03192 (score: 0.5133)
# 9. Compound::MESH:C082410 (score: 0.5063)
# 10. Compound::CHEMBL3545357 (score: 0.5053)
# 11. Compound::DB06345 (score: 0.4993)
# 12. Compound::zinc:ZINC000005650745 (score: 0.4825)
# 13. Compound::DB05668 (score: 0.4765)
# 14. Compound::MESH:C530962 (score: 0.4691)
# 15. Compound::DB02458 (score: 0.4622)
# 16. Compound::DB06098 (score: 0.4589)
# 17. Compound::MESH:D044503 (score: 0.4507)
# 18. Compound::DB04891 (score: 0.4475)
# 19. Compound::MESH:C060090 (score: 0.4441)
# 20. Compound::MESH:C577920 (score: 0.4409)
#
# Disease::SARS-CoV2 nsp5_C145A:
# 1. Compound::DB09116 (score: 0.8790)
# 2. Compound::DB14128 (score: 0.7225)
# 3. Compound::MESH:C581155 (score: 0.6825)
# 4. Compound::DB04531 (score: 0.6139)
# 5. Compound::DB11781 (score: 0.5389)
# 6. Compound::DB00877 (score: 0.4814)
# 7. Compound::DB08878 (score: 0.4691)
# 8. Compound::brenda:222144 (score: 0.4615)
# 9. Compound::DB05483 (score: 0.4497)
# 10. Compound::DB04297 (score: 0.4123)
# 11. Compound::DB06124 (score: 0.3855)
# 12. Compound::brenda:62867 (score: 0.3815)
# 13. Compound::DB06098 (score: 0.3630)
# 14. Compound::DB07350 (score: 0.3548)
# 15. Compound::DB03292 (score: 0.3526)
# 16. Compound::brenda:170760 (score: 0.3508)
# 17. Compound::DB05786 (score: 0.3395)
# 18. Compound::DB14017 (score: 0.3386)
# 19. Compound::DB01593 (score: 0.3174)
# 20. Compound::DB08898 (score: 0.3166)
#
# Disease::SARS-CoV2 nsp6:
# 1. Compound::CHEMBL3137353 (score: 0.8694)
# 2. Compound::rhea:28195 (score: 0.7491)
# 3. Compound::brenda:7480 (score: 0.6624)
# 4. Compound::DB06098 (score: 0.6264)
# 5. Compound::molport:MolPort-003-940-835 (score: 0.5982)
# 6. Compound::CHEMBL566340 (score: 0.5343)
# 7. Compound::DB12563 (score: 0.5338)
# 8. Compound::DB11457 (score: 0.4896)
# 9. Compound::CHEBI:61292 (score: 0.4654)
# 10. Compound::brenda:174399 (score: 0.4623)
# 11. Compound::DB01902 (score: 0.4467)
# 12. Compound::DB01767 (score: 0.4145)
# 13. Compound::brenda:43171 (score: 0.4111)
# 14. Compound::DB04315 (score: 0.4104)
# 15. Compound::rhea:44348 (score: 0.4039)
# 16. Compound::DB09116 (score: 0.3999)
# 17. Compound::DB00157 (score: 0.3727)
# 18. Compound::brenda:36309 (score: 0.3711)
# 19. Compound::DB12971 (score: 0.3462)
# 20. Compound::DB06784 (score: 0.3448)
#
# Disease::SARS-CoV2 nsp7:
# 1. Compound::DB02624 (score: 0.9204)
# 2. Compound::CHEMBL2108628 (score: 0.8870)
# 3. Compound::DB06098 (score: 0.8641)
# 4. Compound::brenda:7480 (score: 0.6841)
# 5. Compound::brenda:12270 (score: 0.5868)
# 6. Compound::MESH:C077992 (score: 0.5640)
# 7. Compound::DB08356 (score: 0.5524)
# 8. Compound::MESH:C459092 (score: 0.5386)
# 9. Compound::DB07115 (score: 0.5145)
# 10. Compound::DB07384 (score: 0.5126)
# 11. Compound::brenda:226203 (score: 0.4884)
# 12. Compound::CHEMBL3137353 (score: 0.4729)
# 13. Compound::brenda:104600 (score: 0.4572)
# 14. Compound::CHEMBL2109193 (score: 0.4161)
# 15. Compound::CHEMBL27885 (score: 0.4126)
# 16. Compound::CHEMBL2107846 (score: 0.4060)
# 17. Compound::gtopdb:10176 (score: 0.4046)
# 18. Compound::DB03158 (score: 0.3934)
# 19. Compound::molport:MolPort-003-940-835 (score: 0.3914)
# 20. Compound::pubchem:407294 (score: 0.3912)
#
# Disease::SARS-CoV2 nsp8:
# 1. Compound::DB06098 (score: 1.4137)
# 2. Compound::brenda:49917 (score: 1.0522)
# 3. Compound::DB07384 (score: 0.9931)
# 4. Compound::bindingdb:50067593 (score: 0.9842)
# 5. Compound::brenda:226203 (score: 0.9520)
# 6. Compound::DB08629 (score: 0.6122)
# 7. Compound::DB12109 (score: 0.6089)
# 8. Compound::MESH:C541938 (score: 0.5924)
# 9. Compound::CHEMBL2108628 (score: 0.5800)
# 10. Compound::CHEMBL2107846 (score: 0.5732)
# 11. Compound::DB08235 (score: 0.5697)
# 12. Compound::DB04803 (score: 0.5696)
# 13. Compound::brenda:36309 (score: 0.5677)
# 14. Compound::molport:MolPort-002-070-273 (score: 0.5391)
# 15. Compound::DB03478 (score: 0.5370)
# 16. Compound::brenda:12356 (score: 0.5357)
# 17. Compound::DB08916 (score: 0.5228)
# 18. Compound::brenda:222144 (score: 0.5188)
# 19. Compound::MESH:C410786 (score: 0.5165)
# 20. Compound::DB12563 (score: 0.5133)
#
# Disease::SARS-CoV2 nsp9:
# 1. Compound::DB00877 (score: 1.7848)
# 2. Compound::DB01229 (score: 1.6073)
# 3. Compound::DB00755 (score: 1.5987)
# 4. Compound::DB02659 (score: 1.5171)
# 5. Compound::DB04216 (score: 1.5161)
# 6. Compound::DB00157 (score: 1.5096)
# 7. Compound::bindingdb:50088446 (score: 1.4259)
# 8. Compound::DB00563 (score: 1.3787)
# 9. Compound::DB00091 (score: 1.2213)
# 10. Compound::DB00313 (score: 1.1648)
# 11. Compound::DB01092 (score: 1.1478)
# 12. Compound::DB00997 (score: 1.0775)
# 13. Compound::DB01034 (score: 1.0582)
# 14. Compound::DB08916 (score: 1.0231)
# 15. Compound::DB08878 (score: 0.9624)
# 16. Compound::DB12695 (score: 0.9498)
# 17. Compound::DB00441 (score: 0.9378)
# 18. Compound::brenda:49917 (score: 0.9308)
# 19. Compound::DB00331 (score: 0.9299)
# 20. Compound::DB08865 (score: 0.9287)
#
# Disease::SARS-CoV2 orf10:
# 1. Compound::MESH:C403563 (score: 0.8142)
# 2. Compound::brenda:226203 (score: 0.7590)
# 3. Compound::brenda:49917 (score: 0.6415)
# 4. Compound::brenda:220871 (score: 0.6348)
# 5. Compound::zinc:ZINC000005650745 (score: 0.6129)
# 6. Compound::DB00877 (score: 0.5890)
# 7. Compound::DB12109 (score: 0.5700)
# 8. Compound::brenda:222144 (score: 0.5623)
# 9. Compound::brenda:104600 (score: 0.5622)
# 10. Compound::brenda:108760 (score: 0.5236)
# 11. Compound::DB03478 (score: 0.5012)
# 12. Compound::MESH:C542662 (score: 0.5010)
# 13. Compound::DB12451 (score: 0.4830)
# 14. Compound::DB08687 (score: 0.4734)
# 15. Compound::CHEMBL432600 (score: 0.4695)
# 16. Compound::DB07344 (score: 0.4600)
# 17. Compound::brenda:71529 (score: 0.4431)
# 18. Compound::CHEMBL1201130 (score: 0.4377)
# 19. Compound::brenda:12356 (score: 0.4318)
# 20. Compound::MESH:C530962 (score: 0.4280)
#
# Disease::SARS-CoV2 orf3a:
# 1. Compound::molport:MolPort-003-940-835 (score: 0.9416)
# 2. Compound::brenda:7480 (score: 0.9309)
# 3. Compound::brenda:174399 (score: 0.8860)
# 4. Compound::brenda:43171 (score: 0.8701)
# 5. Compound::brenda:21348 (score: 0.7128)
# 6. Compound::CHEMBL3137353 (score: 0.6982)
# 7. Compound::DB00157 (score: 0.5741)
# 8. Compound::bindingdb:50028010 (score: 0.5738)
# 9. Compound::rhea:44348 (score: 0.5691)
# 10. Compound::DB12971 (score: 0.5096)
# 11. Compound::molport:MolPort-046-588-736 (score: 0.4909)
# 12. Compound::brenda:138728 (score: 0.4886)
# 13. Compound::DB06098 (score: 0.4881)
# 14. Compound::rhea:28195 (score: 0.4756)
# 15. Compound::DB04141 (score: 0.4672)
# 16. Compound::DB02624 (score: 0.4365)
# 17. Compound::DB12424 (score: 0.4206)
# 18. Compound::brenda:12270 (score: 0.4135)
# 19. Compound::DB08185 (score: 0.4122)
# 20. Compound::DB04869 (score: 0.3909)
#
# Disease::SARS-CoV2 orf3b:
# 1. Compound::CHEBI:18186 (score: 1.3714)
# 2. Compound::bindingdb:50088446 (score: 1.3483)
# 3. Compound::DB04315 (score: 1.2549)
# 4. Compound::DB11799 (score: 1.2421)
# 5. Compound::CHEBI:61292 (score: 1.2235)
# 6. Compound::DB04137 (score: 1.1277)
# 7. Compound::DB00171 (score: 0.9156)
# 8. Compound::DB00877 (score: 0.8193)
# 9. Compound::DB11575 (score: 0.7227)
# 10. Compound::DB02015 (score: 0.6993)
# 11. Compound::DB03203 (score: 0.6979)
# 12. Compound::brenda:7480 (score: 0.6877)
# 13. Compound::DB00091 (score: 0.6456)
# 14. Compound::DB08629 (score: 0.6428)
# 15. Compound::DB06734 (score: 0.6328)
# 16. Compound::DB04207 (score: 0.6293)
# 17. Compound::DB03401 (score: 0.6148)
# 18. Compound::rhea:57952 (score: 0.6095)
# 19. Compound::brenda:217403 (score: 0.6095)
# 20. Compound::DB04531 (score: 0.6091)
#
# Disease::SARS-CoV2 orf6:
# 1. Compound::DB00157 (score: 1.7227)
# 2. Compound::DB04216 (score: 1.6086)
# 3. Compound::bindingdb:50088446 (score: 1.3792)
# 4. Compound::DB00755 (score: 1.0828)
# 5. Compound::DB00997 (score: 1.0548)
# 6. Compound::DB03461 (score: 1.0462)
# 7. Compound::brenda:49917 (score: 1.0301)
# 8. Compound::brenda:215295 (score: 1.0081)
# 9. Compound::bindingdb:50067593 (score: 1.0035)
# 10. Compound::DB05959 (score: 0.9882)
# 11. Compound::DB00877 (score: 0.9844)
# 12. Compound::DB01229 (score: 0.8895)
# 13. Compound::DB01232 (score: 0.8646)
# 14. Compound::bindingdb:50215393 (score: 0.8512)
# 15. Compound::DB04862 (score: 0.8486)
# 16. Compound::DB12695 (score: 0.8296)
# 17. Compound::molport:MolPort-046-588-736 (score: 0.8131)
# 18. Compound::DB00091 (score: 0.8114)
# 19. Compound::brenda:21348 (score: 0.8081)
# 20. Compound::zinc:ZINC000005650745 (score: 0.7687)
#
# Disease::SARS-CoV2 orf7a:
# 1. Compound::CHEBI:18186 (score: 1.3452)
# 2. Compound::DB00157 (score: 0.9531)
# 3. Compound::CHEBI:17822 (score: 0.9274)
# 4. Compound::DB04630 (score: 0.8735)
# 5. Compound::DB09130 (score: 0.8515)
# 6. Compound::MESH:D014443 (score: 0.7851)
# 7. Compound::DB01065 (score: 0.7583)
# 8. Compound::DB00898 (score: 0.7347)
# 9. Compound::DB01593 (score: 0.7294)
# 10. Compound::DB02010 (score: 0.7273)
# 11. Compound::DB01221 (score: 0.7078)
# 12. Compound::MESH:C076029 (score: 0.6834)
# 13. Compound::DB00295 (score: 0.6408)
# 14. Compound::MESH:D016627 (score: 0.6239)
# 15. Compound::rhea:28195 (score: 0.6233)
# 16. Compound::MESH:D008094 (score: 0.6005)
# 17. Compound::DB00363 (score: 0.5927)
# 18. Compound::rhea:44348 (score: 0.5902)
# 19. Compound::DB00734 (score: 0.5893)
# 20. Compound::DB14546 (score: 0.5657)
#
# Disease::SARS-CoV2 orf8:
# 1. Compound::DB06098 (score: 2.2218)
# 2. Compound::CHEMBL3137353 (score: 1.1511)
# 3. Compound::CHEMBL566340 (score: 1.0782)
# 4. Compound::pubchem:407294 (score: 1.0444)
# 5. Compound::CHEMBL2109193 (score: 0.9673)
# 6. Compound::brenda:12270 (score: 0.9326)
# 7. Compound::DB09116 (score: 0.9000)
# 8. Compound::brenda:104600 (score: 0.8787)
# 9. Compound::brenda:226203 (score: 0.8695)
# 10. Compound::CHEMBL2108628 (score: 0.8297)
# 11. Compound::DB01902 (score: 0.8268)
# 12. Compound::CHEMBL27885 (score: 0.8174)
# 13. Compound::DB08356 (score: 0.7839)
# 14. Compound::DB01969 (score: 0.7699)
# 15. Compound::brenda:222144 (score: 0.7691)
# 16. Compound::DB02369 (score: 0.7567)
# 17. Compound::DB03478 (score: 0.7504)
# 18. Compound::DB02423 (score: 0.7244)
# 19. Compound::DB05362 (score: 0.7232)
# 20. Compound::DB08232 (score: 0.7202)
#
# Disease::SARS-CoV2 orf9b:
# 1. Compound::DB00877 (score: 2.4574)
# 2. Compound::DB04315 (score: 2.0666)
# 3. Compound::DB01229 (score: 1.9536)
# 4. Compound::bindingdb:50088446 (score: 1.9317)
# 5. Compound::DB04216 (score: 1.8824)
# 6. Compound::DB00171 (score: 1.8683)
# 7. Compound::DB12695 (score: 1.6958)
# 8. Compound::CHEBI:18186 (score: 1.6942)
# 9. Compound::CHEBI:61292 (score: 1.6057)
# 10. Compound::DB01118 (score: 1.5142)
# 11. Compound::DB04137 (score: 1.5009)
# 12. Compound::DB01092 (score: 1.3177)
# 13. Compound::DB00091 (score: 1.2989)
# 14. Compound::MESH:D014443 (score: 1.2682)
# 15. Compound::DB08931 (score: 1.2464)
# 16. Compound::brenda:21348 (score: 1.2298)
# 17. Compound::DB00563 (score: 1.2125)
# 18. Compound::DB00441 (score: 1.1937)
# 19. Compound::DB00997 (score: 1.1917)
# 20. Compound::DB00641 (score: 1.1588)
#
# Disease::SARS-CoV2 orf9c:
# 1. Compound::DB06098 (score: 1.5541)
# 2. Compound::brenda:7480 (score: 1.1981)
# 3. Compound::CHEMBL3137353 (score: 1.1599)
# 4. Compound::molport:MolPort-003-940-835 (score: 1.1107)
# 5. Compound::brenda:43171 (score: 0.7094)
# 6. Compound::DB01902 (score: 0.6973)
# 7. Compound::brenda:174399 (score: 0.6740)
# 8. Compound::CHEMBL566340 (score: 0.6548)
# 9. Compound::brenda:12270 (score: 0.6470)
# 10. Compound::CHEMBL2108628 (score: 0.6342)
# 11. Compound::brenda:36309 (score: 0.6233)
# 12. Compound::pubchem:407294 (score: 0.5928)
# 13. Compound::rhea:28195 (score: 0.5872)
# 14. Compound::brenda:222144 (score: 0.5870)
# 15. Compound::rhea:44348 (score: 0.5832)
# 16. Compound::molport:MolPort-046-588-736 (score: 0.5516)
# 17. Compound::CHEMBL27885 (score: 0.5476)
# 18. Compound::brenda:226203 (score: 0.5055)
# 19. Compound::DB06784 (score: 0.4928)
# 20. Compound::DB08356 (score: 0.4585)
#
# Disease::MESH:D045169:
# 1. Compound::DB01234 (score: 5.5053)
# 2. Compound::DB00741 (score: 5.2695)
# 3. Compound::DB00898 (score: 5.2607)
# 4. Compound::DB09130 (score: 4.9308)
# 5. Compound::DB00945 (score: 4.9068)
# 6. Compound::DB00860 (score: 4.7082)
# 7. Compound::MESH:D013256 (score: 4.7074)
# 8. Compound::DB00635 (score: 4.6808)
# 9. Compound::DB00563 (score: 4.6681)
# 10. Compound::DB00091 (score: 4.6382)
# 11. Compound::DB00917 (score: 4.6227)
# 12. Compound::DB00515 (score: 4.5727)
# 13. Compound::DB00544 (score: 4.5434)
# 14. Compound::DB00959 (score: 4.4955)
# 15. Compound::DB00126 (score: 4.4470)
# 16. Compound::DB00859 (score: 4.4225)
# 17. Compound::DB09140 (score: 4.4040)
# 18. Compound::DB01593 (score: 4.3951)
# 19. Compound::DB00755 (score: 4.3848)
# 20. Compound::MESH:D019344 (score: 4.3605)
#
# Disease::MESH:D045473:
# 1. Compound::CHEBI:18186 (score: 1.9951)
# 2. Compound::MESH:D014443 (score: 1.2395)
# 3. Compound::DB07045 (score: 1.2338)
# 4. Compound::MESH:C031563 (score: 1.1387)
# 5. Compound::brenda:49917 (score: 0.8458)
# 6. Compound::brenda:7480 (score: 0.7005)
# 7. Compound::DB07125 (score: 0.6951)
# 8. Compound::MESH:C551994 (score: 0.6806)
# 9. Compound::MESH:C077992 (score: 0.6745)
# 10. Compound::CHEMBL2108628 (score: 0.6658)
# 11. Compound::DB08736 (score: 0.6597)
# 12. Compound::MESH:D019394 (score: 0.6545)
# 13. Compound::DB07455 (score: 0.6282)
# 14. Compound::DB07546 (score: 0.6142)
# 15. Compound::brenda:226203 (score: 0.6089)
# 16. Compound::CHEMBL2109330 (score: 0.6066)
# 17. Compound::CHEBI:46741 (score: 0.5924)
# 18. Compound::DB02570 (score: 0.5901)
# 19. Compound::CHEMBL2012938 (score: 0.5860)
# 20. Compound::MESH:C082874 (score: 0.5844)
#
# Disease::MESH:D001351:
# 1. Compound::CHEBI:18186 (score: 2.3943)
# 2. Compound::MESH:D014443 (score: 1.0285)
# 3. Compound::MESH:C031563 (score: 1.0221)
# 4. Compound::CHEBI:61292 (score: 1.0049)
# 5. Compound::DB07340 (score: 0.8309)
# 6. Compound::MESH:C014674 (score: 0.8271)
# 7. Compound::brenda:49917 (score: 0.7721)
# 8. Compound::DB07045 (score: 0.7511)
# 9. Compound::DB09107 (score: 0.7169)
# 10. Compound::MESH:C030986 (score: 0.6425)
# 11. Compound::CHEMBL3545320 (score: 0.6156)
# 12. Compound::DB02097 (score: 0.6111)
# 13. Compound::DB05786 (score: 0.6057)
# 14. Compound::MESH:C005066 (score: 0.5881)
# 15. Compound::CHEBI:37898 (score: 0.5821)
# 16. Compound::MESH:D020111 (score: 0.5701)
# 17. Compound::DB07125 (score: 0.5692)
# 18. Compound::MESH:C414024 (score: 0.5673)
# 19. Compound::MESH:C516714 (score: 0.5649)
# 20. Compound::MESH:C528407 (score: 0.5639)
#
# Disease::MESH:D065207:
# 1. Compound::DB02821 (score: 0.4843)
# 2. Compound::DB03245 (score: 0.4002)
# 3. Compound::CHEBI:33704 (score: 0.3978)
# 4. Compound::DB06098 (score: 0.3874)
# 5. Compound::DB07115 (score: 0.3816)
# 6. Compound::CHEBI:17822 (score: 0.3780)
# 7. Compound::DB01593 (score: 0.3637)
# 8. Compound::MESH:D011144 (score: 0.3487)
# 9. Compound::MESH:C031563 (score: 0.3467)
# 10. Compound::brenda:62867 (score: 0.3308)
# 11. Compound::DB04676 (score: 0.3237)
# 12. Compound::DB06124 (score: 0.3195)
# 13. Compound::DB15570 (score: 0.3168)
# 14. Compound::DB08235 (score: 0.3103)
# 15. Compound::CHEMBL2108709 (score: 0.3060)
# 16. Compound::CHEBI:74858 (score: 0.2975)
# 17. Compound::DB02884 (score: 0.2974)
# 18. Compound::CHEMBL3301672 (score: 0.2968)
# 19. Compound::CHEMBL2109481 (score: 0.2752)
# 20. Compound::DB07455 (score: 0.2741)
#
# Disease::MESH:D028941:
# 1. Compound::hmdb:HMDB0010366 (score: 0.4871)
# 2. Compound::DB01989 (score: 0.4380)
# 3. Compound::MESH:C105171 (score: 0.4229)
# 4. Compound::CHEMBL2108709 (score: 0.4130)
# 5. Compound::DB06098 (score: 0.3598)
# 6. Compound::CHEMBL3301672 (score: 0.3513)
# 7. Compound::DB11571 (score: 0.3397)
# 8. Compound::MESH:D053683 (score: 0.3368)
# 9. Compound::MESH:C559289 (score: 0.3337)
# 10. Compound::CHEBI:50016 (score: 0.3211)
# 11. Compound::MESH:C077992 (score: 0.3081)
# 12. Compound::DB05309 (score: 0.2978)
# 13. Compound::MESH:D004047 (score: 0.2947)
# 14. Compound::MESH:C000599091 (score: 0.2896)
# 15. Compound::DB04318 (score: 0.2835)
# 16. Compound::DB06757 (score: 0.2824)
# 17. Compound::MESH:C011729 (score: 0.2729)
# 18. Compound::MESH:C518545 (score: 0.2717)
# 19. Compound::CHEBI:47853 (score: 0.2697)
# 20. Compound::DB01969 (score: 0.2596)
#
# Disease::MESH:D058957:
# 1. Compound::CHEBI:18186 (score: 1.4183)
# 2. Compound::MESH:D014443 (score: 0.7457)
# 3. Compound::CHEBI:17822 (score: 0.4622)
# 4. Compound::DB01593 (score: 0.4414)
# 5. Compound::DB00004 (score: 0.4187)
# 6. Compound::MESH:C097613 (score: 0.4149)
# 7. Compound::CHEBI:61292 (score: 0.3893)
# 8. Compound::DB00515 (score: 0.3752)
# 9. Compound::CHEBI:74956 (score: 0.3624)
# 10. Compound::MESH:C471405 (score: 0.3586)
# 11. Compound::DB00441 (score: 0.3307)
# 12. Compound::DB12028 (score: 0.3296)
# 13. Compound::DB00309 (score: 0.3171)
# 14. Compound::MESH:C005066 (score: 0.2954)
# 15. Compound::MESH:C419708 (score: 0.2906)
# 16. Compound::DB04104 (score: 0.2832)
# 17. Compound::DB00115 (score: 0.2674)
# 18. Compound::DB01229 (score: 0.2660)
# 19. Compound::DB00076 (score: 0.2586)
# 20. Compound::MESH:C488369 (score: 0.2483)
#
# Disease::MESH:D006517:
# 1. Compound::CHEBI:18186 (score: 2.2730)
# 2. Compound::MESH:D014443 (score: 1.4917)
# 3. Compound::DB07045 (score: 1.4801)
# 4. Compound::MESH:C031563 (score: 1.4708)
# 5. Compound::DB01229 (score: 1.3199)
# 6. Compound::bindingdb:50088446 (score: 1.2835)
# 7. Compound::DB00877 (score: 1.2287)
# 8. Compound::brenda:49917 (score: 1.2006)
# 9. Compound::DB11457 (score: 1.0651)
# 10. Compound::CHEBI:61292 (score: 1.0517)
# 11. Compound::brenda:7480 (score: 1.0055)
# 12. Compound::DB00171 (score: 0.9294)
# 13. Compound::DB05786 (score: 0.9286)
# 14. Compound::brenda:226203 (score: 0.8960)
# 15. Compound::DB11759 (score: 0.8783)
# 16. Compound::CHEMBL2108628 (score: 0.8432)
# 17. Compound::MESH:C419708 (score: 0.8291)
# 18. Compound::DB08313 (score: 0.8179)
# 19. Compound::DB00997 (score: 0.8166)
# 20. Compound::MESH:D016627 (score: 0.8045)

# %%
def get_compounds_with_treatments(graph):
    """
    Get list of compounds that have treatment data associated with COVID-19.
    Returns list of compounds and count.
    """
    # Initialize an empty list to store compound nodes.
    compounds = []

    # Iterate through all nodes and their attributes.
    for node, attributes in graph.nodes(data=True):
        # Check if the node is a string, starts with 'Compound::', and contains 'treatment_data' in its attributes.
        if (isinstance(node, str) and
            node.startswith('Compound::') and
            'treatment_data' in attributes):
            compounds.append(node)

    return compounds, len(compounds)

# Get the compounds and count
compounds, num_compounds = get_compounds_with_treatments(graph)
print(compounds)
print(num_compounds)
# Out:
# ['Compound::DB01087', 'Compound::DB01072', 'Compound::DB06817', 'Compound::DB00773', 'Compound::DB01392', 'Compound::DB00539', 'Compound::DB07795', 'Compound::DB13997', 'Compound::DB09299', 'Compound::DB00608', 'Compound::DB14126', 'Compound::DB00091', 'Compound::DB00198', 'Compound::DB00811', 'Compound::DB09026', 'Compound::DB08934', 'Compound::DB00220', 'Compound::DB11779', 'Compound::DB00328', 'Compound::DB04786', 'Compound::DB00482', 'Compound::DB01015', 'Compound::DB09102', 'Compound::DB01264', 'Compound::DB01645', 'Compound::DB00822', 'Compound::DB09065', 'Compound::DB12610', 'Compound::DB00831', 'Compound::DB00457', 'Compound::DB04115', 'Compound::DB01041', 'Compound::DB00722', 'Compound::DB00213', 'Compound::DB00133', 'Compound::DB06803', 'Compound::DB12270', 'Compound::DB00319', 'Compound::DB11952', 'Compound::DB00302', 'Compound::DB00199', 'Compound::DB13925', 'Compound::DB00143', 'Compound::DB09061', 'Compound::DB14810', 'Compound::DB00673', 'Compound::DB00159', 'Compound::DB00966', 'Compound::DB01190', 'Compound::DB04224', 'Compound::DB11859', 'Compound::DB08868', 'Compound::DB06699', 'Compound::DB09322', 'Compound::DB00146', 'Compound::DB06210', 'Compound::DB11758', 'Compound::DB00140', 'Compound::DB01075', 'Compound::DB04862', 'Compound::DB01262', 'Compound::DB00881', 'Compound::DB00855', 'Compound::DB01430', 'Compound::DB06605', 'Compound::DB00151', 'Compound::DB00316', 'Compound::DB00126', 'Compound::DB00569', 'Compound::DB01410', 'Compound::DB12582', 'Compound::DB01042', 'Compound::DB00471', 'Compound::DB00264', 'Compound::DB00281', 'Compound::DB00507', 'Compound::DB11697', 'Compound::DB00920', 'Compound::DB01390', 'Compound::DB01029', 'Compound::DB02701', 'Compound::DB00848', 'Compound::DB00480', 'Compound::DB00825', 'Compound::DB01088', 'Compound::DB01050', 'Compound::DB00477', 'Compound::DB01115', 'Compound::DB00761', 'Compound::DB06209', 'Compound::DB06403', 'Compound::DB15446', 'Compound::DB00758', 'Compound::DB08882', 'Compound::DB04977', 'Compound::DB00006', 'Compound::DB06228', 'Compound::DB12580', 'Compound::DB04951', 'Compound::DB00278', 'Compound::DB01126', 'Compound::DB12668', 'Compound::DB00691', 'Compound::DB11863', 'Compound::DB00980', 'Compound::DB00783', 'Compound::DB00945', 'Compound::DB12614', 'Compound::DB01234', 'Compound::DB00806', 'Compound::DB01118', 'Compound::DB01060', 'Compound::DB06151', 'Compound::DB09241', 'Compound::DB06280', 'Compound::DB09154', 'Compound::DB11651', 'Compound::DB05676', 'Compound::DB01197', 'Compound::DB06515', 'Compound::DB00818', 'Compound::DB00877', 'Compound::DB00878', 'Compound::DB00155', 'Compound::DB05076', 'Compound::DB11720', 'Compound::DB01076', 'Compound::DB00169', 'Compound::DB00704', 'Compound::DB00982', 'Compound::DB00755', 'Compound::DB00661', 'Compound::DB00338', 'Compound::DB11817', 'Compound::DB00472', 'Compound::DB06717', 'Compound::DB01137', 'Compound::DB01212', 'Compound::DB00683', 'Compound::DB00313', 'Compound::DB15035', 'Compound::DB00542', 'Compound::DB00177', 'Compound::DB01222', 'Compound::DB00613', 'Compound::DB11574', 'Compound::DB09053', 'Compound::DB00796', 'Compound::DB09112', 'Compound::DB09130', 'Compound::DB00788', 'Compound::DB00435', 'Compound::DB05511', 'Compound::DB01039', 'Compound::DB11590', 'Compound::DB09019', 'Compound::DB00741', 'Compound::DB12612', 'Compound::DB00396', 'Compound::DB12010', 'Compound::DB08822', 'Compound::DB04854', 'Compound::DB00653', 'Compound::DB11526', 'Compound::DB01593', 'Compound::DB00497', 'Compound::DB00148', 'Compound::DB00121', 'Compound::DB00178', 'Compound::DB08995', 'Compound::DB03904', 'Compound::DB01216', 'Compound::DB13729', 'Compound::DB00519', 'Compound::DB04743', 'Compound::DB01132', 'Compound::DB01065', 'Compound::DB01236', 'Compound::DB00753', 'Compound::DB01240', 'Compound::DB09075', 'Compound::DB00916', 'Compound::DB00203', 'Compound::DB00583', 'Compound::DB04835', 'Compound::DB00176', 'Compound::DB05266', 'Compound::DB00864', 'Compound::DB00275', 'Compound::DB01394', 'Compound ...
# 451

# %%
def analyze_predictions_vs_treatments(predictions, actual_compounds):
    """
    Analyze how many predicted compounds for each disease are actual treatment compounds.
    """
    analysis_results = {}

    # Loop through all predicted compounds and respective diseases
    for disease, predicted_compounds in predictions.items():
        if predicted_compounds:
            # Get just the compound names from predictions (without scores)
            predicted_set = set(compound for compound, _ in predicted_compounds)

            # Find overlap with actual compounds
            overlap = predicted_set.intersection(set(actual_compounds))

            # Calculate percentage
            percentage = (len(overlap) / len(predicted_compounds)) * 100

            # Store results
            analysis_results[disease] = {
                'overlap_count': len(overlap),
                'overlap_percentage': percentage,
                'overlapping_compounds': list(overlap)
            }

            # Print results
            print(f"\n{disease}:")
            print(f"Number of predicted compounds in treatment database: {len(overlap)}/20")
            print(f"Percentage: {percentage:.2f}%")
            print("Overlapping compounds:")
            for compound in overlap:
                print(f"- {compound}")

    return analysis_results

# First get predictions
relation = "DRKG::Treats::Compound:Disease"
predictions = get_top_predictions(
    pipeline_result.model,
    training_factory,
    relation,
    COV_disease_list
)

# Then get actual treatment compounds
actual_compounds, num_actual = get_compounds_with_treatments(graph)

# Analyze overlap
print(f"\nTotal number of compounds with actual treatment data: {num_actual}")
analysis = analyze_predictions_vs_treatments(predictions, actual_compounds)
# Out:
# Total number of compounds with actual treatment data: 451
#
# Disease::SARS-CoV2 E:
# Number of predicted compounds in treatment database: 0/20
# Percentage: 0.00%
# Overlapping compounds:
#
# Disease::SARS-CoV2 M:
# Number of predicted compounds in treatment database: 0/20
# Percentage: 0.00%
# Overlapping compounds:
#
# Disease::SARS-CoV2 N:
# Number of predicted compounds in treatment database: 1/20
# Percentage: 5.00%
# Overlapping compounds:
# - Compound::DB00877
#
# Disease::SARS-CoV2 Spike:
# Number of predicted compounds in treatment database: 8/20
# Percentage: 40.00%
# Overlapping compounds:
# - Compound::DB00091
# - Compound::DB01098
# - Compound::DB14513
# - Compound::DB00602
# - Compound::DB00468
# - Compound::DB00877
# - Compound::DB00916
# - Compound::DB00563
#
# Disease::SARS-CoV2 nsp1:
# Number of predicted compounds in treatment database: 0/20
# Percentage: 0.00%
# Overlapping compounds:
#
# Disease::SARS-CoV2 nsp10:
# Number of predicted compounds in treatment database: 8/20
# Percentage: 40.00%
# Overlapping compounds:
# - Compound::DB00091
# - Compound::DB00641
# - Compound::DB12010
# - Compound::DB00877
# - Compound::DB09079
# - Compound::DB04216
# - Compound::DB11091
# - Compound::DB00563
#
# Disease::SARS-CoV2 nsp11:
# Number of predicted compounds in treatment database: 1/20
# Percentage: 5.00%
# Overlapping compounds:
# - Compound::DB00877
#
# Disease::SARS-CoV2 nsp12:
# Number of predicted compounds in treatment database: 0/20
# Percentage: 0.00%
# Overlapping compounds:
#
# Disease::SARS-CoV2 nsp13:
# Number of predicted compounds in treatment database: 4/20
# Percentage: 20.00%
# Overlapping compounds:
# - Compound::DB00877
# - Compound::DB01115
# - Compound::DB01118
# - Compound::DB12010
#
# Disease::SARS-CoV2 nsp14:
# Number of predicted compounds in treatment database: 1/20
# Percentage: 5.00%
# Overlapping compounds:
# - Compound::DB01098
#
# Disease::SARS-CoV2 nsp15:
# Number of predicted compounds in treatment database: 8/20
# Percentage: 40.00%
# Overlapping compounds:
# - Compound::DB00091
# - Compound::DB00641
# - Compound::DB12010
# - Compound::DB00877
# - Compound::DB09079
# - Compound::DB04216
# - Compound::DB01115
# - Compound::DB01118
#
# Disease::SARS-CoV2 nsp2:
# Number of predicted compounds in treatment database: 0/20
# Percentage: 0.00%
# Overlapping compounds:
#
# Disease::SARS-CoV2 nsp4:
# Number of predicted compounds in treatment database: 0/20
# Percentage: 0.00%
# Overlapping compounds:
#
# Disease::SARS-CoV2 nsp5:
# Number of predicted compounds in treatment database: 0/20
# Percentage: 0.00%
# Overlapping compounds:
#
# Disease::SARS-CoV2 nsp5_C145A:
# Number of predicted compounds in treatment database: 2/20
# Percentage: 10.00%
# Overlapping compounds:
# - Compound::DB00877
# - Compound::DB01593
#
# Disease::SARS-CoV2 nsp6:
# Number of predicted compounds in treatment database: 0/20
# Percentage: 0.00%
# Overlapping compounds:
#
# Disease::SARS-CoV2 nsp7:
# Number of predicted compounds in treatment database: 0/20
# Percentage: 0.00%
# Overlapping compounds:
#
# Disease::SARS-CoV2 nsp8:
# Number of predicted compounds in treatment database: 0/20
# Percentage: 0.00%
# Overlapping compounds:
#
# Disease::SARS-CoV2 nsp9:
# Number of predicted compounds in treatment database: 7/20
# Percentage: 35.00%
# Overlapping compounds:
# - Compound::DB00091
# - Compound::DB00755
# - Compound::DB00877
# - Compound::DB00313
# - Compound::DB00331
# - Compound::DB04216
# - Compound::DB00563
#
# Disease::SARS-CoV2 orf10:
# Number of predicted compounds in treatment database: 1/20
# Percentage: 5.00%
# Overlapping compounds:
# - Compound::DB00877
#
# Disease::SARS-CoV2 orf3a:
# Number of predicted compounds in treatment database: 0/20
# Percentage: 0.00%
# Overlapping compounds:
#
# Disease::SARS-CoV2 orf3b:
# Number of predicted compounds in treatment database: 2/20
# Percentage: 10.00%
# Overlapping compounds:
# - Compound::DB00091
# - Compound::DB00877
#
# Disease::SARS-CoV2 orf6:
# Number of predicted compounds in treatment database: 5/20
# Percentage: 25.00%
# Overlapping compounds:
# - Compound::DB00091
# - Compound::DB00755
# - Compound::DB04862
# - Compound::DB00877
# - Compound::DB04216
#
# Disease::SARS-CoV2 orf7a:
# Number of predicted compounds in treatment database: 6/20
# Percentage: 30.00%
# Overlapping compounds:
# - Compound::DB00898
# - Compound::DB01221
# - Compound::DB00295
# - Compound::DB09130
# - Compound::DB01593
# - Compound::DB01065
#
# Disease::SARS-CoV2 orf8:
# Number of predicted compounds in treatment database: 0/20
# Percentage: 0.00%
# Overlapping compounds:
#
# Disease::SARS-CoV2 orf9b:
# Number of predicted compounds in treatment database: 6/20
# Percentage: 30.00%
# Overlapping compounds:
# - Compound::DB00091
# - Compound::DB00641
# - Compound::DB00877
# - Compound::DB04216
# - Compound::DB01118
# - Compound::DB00563
#
# Disease::SARS-CoV2 orf9c:
# Number of predicted compounds in treatment database: 0/20
# Percentage: 0.00%
# Overlapping compounds:
#
# Disease::MESH:D045169:
# Number of predicted compounds in treatment database: 14/20
# Percentage: 70.00%
# Overlapping compounds:
# - Compound::DB01234
# - Compound::DB00091
# - Compound::DB00755
# - Compound::DB00898
# - Compound::DB00860
# - Compound::DB00126
# - Compound::DB00959
# - Compound::DB00741
# - Compound::DB00635
# - Compound::DB09130
# - Compound::DB09140
# - Compound::DB01593
# - Compound::DB00945
# - Compound::DB00563
#
# Disease::MESH:D045473:
# Number of predicted compounds in treatment database: 0/20
# Percentage: 0.00%
# Overlapping compounds:
#
# Disease::MESH:D001351:
# Number of predicted compounds in treatment database: 0/20
# Percentage: 0.00%
# Overlapping compounds:
#
# Disease::MESH:D065207:
# Number of predicted compounds in treatment database: 1/20
# Percentage: 5.00%
# Overlapping compounds:
# - Compound::DB01593
#
# Disease::MESH:D028941:
# Number of predicted compounds in treatment database: 0/20
# Percentage: 0.00%
# Overlapping compounds:
#
# Disease::MESH:D058957:
# Number of predicted compounds in treatment database: 2/20
# Percentage: 10.00%
# Overlapping compounds:
# - Compound::DB00115
# - Compound::DB01593
#
# Disease::MESH:D006517:
# Number of predicted compounds in treatment database: 1/20
# Percentage: 5.00%
# Overlapping compounds:
# - Compound::DB00877
